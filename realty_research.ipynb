# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных из файла</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Пропуски" data-toc-modified-id="Пропуски-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Пропуски</a></span><ul class="toc-item"><li><span><a href="#total_images" data-toc-modified-id="total_images-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>total_images</a></span></li><li><span><a href="#last_price" data-toc-modified-id="last_price-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>last_price</a></span></li><li><span><a href="#total_area" data-toc-modified-id="total_area-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>total_area</a></span></li><li><span><a href="#first_day_exposition" data-toc-modified-id="first_day_exposition-2.1.4"><span class="toc-item-num">2.1.4&nbsp;&nbsp;</span>first_day_exposition</a></span></li><li><span><a href="#rooms" data-toc-modified-id="rooms-2.1.5"><span class="toc-item-num">2.1.5&nbsp;&nbsp;</span>rooms</a></span></li><li><span><a href="#ceiling_height" data-toc-modified-id="ceiling_height-2.1.6"><span class="toc-item-num">2.1.6&nbsp;&nbsp;</span>ceiling_height</a></span></li><li><span><a href="#floors_total" data-toc-modified-id="floors_total-2.1.7"><span class="toc-item-num">2.1.7&nbsp;&nbsp;</span>floors_total</a></span></li><li><span><a href="#living_area-&amp;-kitchen_area" data-toc-modified-id="living_area-&amp;-kitchen_area-2.1.8"><span class="toc-item-num">2.1.8&nbsp;&nbsp;</span>living_area &amp; kitchen_area</a></span></li><li><span><a href="#floor" data-toc-modified-id="floor-2.1.9"><span class="toc-item-num">2.1.9&nbsp;&nbsp;</span>floor</a></span></li><li><span><a href="#is_apartment" data-toc-modified-id="is_apartment-2.1.10"><span class="toc-item-num">2.1.10&nbsp;&nbsp;</span>is_apartment</a></span></li><li><span><a href="#studio" data-toc-modified-id="studio-2.1.11"><span class="toc-item-num">2.1.11&nbsp;&nbsp;</span>studio</a></span></li><li><span><a href="#open_plan" data-toc-modified-id="open_plan-2.1.12"><span class="toc-item-num">2.1.12&nbsp;&nbsp;</span>open_plan</a></span></li><li><span><a href="#balcony" data-toc-modified-id="balcony-2.1.13"><span class="toc-item-num">2.1.13&nbsp;&nbsp;</span>balcony</a></span></li><li><span><a href="#locality_name" data-toc-modified-id="locality_name-2.1.14"><span class="toc-item-num">2.1.14&nbsp;&nbsp;</span>locality_name</a></span></li><li><span><a href="#airports_nearest" data-toc-modified-id="airports_nearest-2.1.15"><span class="toc-item-num">2.1.15&nbsp;&nbsp;</span>airports_nearest</a></span></li><li><span><a href="#cityCenters_nearest" data-toc-modified-id="cityCenters_nearest-2.1.16"><span class="toc-item-num">2.1.16&nbsp;&nbsp;</span>cityCenters_nearest</a></span></li><li><span><a href="#parks_around3000" data-toc-modified-id="parks_around3000-2.1.17"><span class="toc-item-num">2.1.17&nbsp;&nbsp;</span>parks_around3000</a></span></li><li><span><a href="#parks_nearest" data-toc-modified-id="parks_nearest-2.1.18"><span class="toc-item-num">2.1.18&nbsp;&nbsp;</span>parks_nearest</a></span></li><li><span><a href="#ponds_around3000" data-toc-modified-id="ponds_around3000-2.1.19"><span class="toc-item-num">2.1.19&nbsp;&nbsp;</span>ponds_around3000</a></span></li><li><span><a href="#ponds_nearest" data-toc-modified-id="ponds_nearest-2.1.20"><span class="toc-item-num">2.1.20&nbsp;&nbsp;</span>ponds_nearest</a></span></li><li><span><a href="#days_exposition" data-toc-modified-id="days_exposition-2.1.21"><span class="toc-item-num">2.1.21&nbsp;&nbsp;</span>days_exposition</a></span></li></ul></li><li><span><a href="#Дубликаты" data-toc-modified-id="Дубликаты-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Дубликаты</a></span></li><li><span><a href="#Вывод-предобработки" data-toc-modified-id="Вывод-предобработки-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Вывод предобработки</a></span></li></ul></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span><ul class="toc-item"><li><span><a href="#Цена-квадратного-метра" data-toc-modified-id="Цена-квадратного-метра-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Цена квадратного метра</a></span></li><li><span><a href="#День-недели,-месяц-и-год-публикации-объявления" data-toc-modified-id="День-недели,-месяц-и-год-публикации-объявления-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>День недели, месяц и год публикации объявления</a></span></li><li><span><a href="#Этаж-квартиры;-варианты-—-первый,-последний,-другой-(firtst,-last,-other)" data-toc-modified-id="Этаж-квартиры;-варианты-—-первый,-последний,-другой-(firtst,-last,-other)-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Этаж квартиры; варианты — первый, последний, другой (firtst, last, other)</a></span></li><li><span><a href="#Cоотношение-жилой-и-общей-площади,-а-также-отношение-площади-кухни-к-общей." data-toc-modified-id="Cоотношение-жилой-и-общей-площади,-а-также-отношение-площади-кухни-к-общей.-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Cоотношение жилой и общей площади, а также отношение площади кухни к общей.</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Изучение-параметров---площадь,-цена,-число-комнат,-высота-потолков.-Построение-гистограммы-для-каждого-параметра." data-toc-modified-id="Изучение-параметров---площадь,-цена,-число-комнат,-высота-потолков.-Построение-гистограммы-для-каждого-параметра.-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Изучение параметров - площадь, цена, число комнат, высота потолков. Построение гистограммы для каждого параметра.</a></span></li><li><span><a href="#Изучите-время-продажи-квартиры.-Постройте-гистограмму.-Посчитайте-среднее-и-медиану.-Опишите,-сколько-обычно-занимает-продажа.-Когда-можно-считать,-что-продажи-прошли-очень-быстро,-а-когда-необычно-долго?" data-toc-modified-id="Изучите-время-продажи-квартиры.-Постройте-гистограмму.-Посчитайте-среднее-и-медиану.-Опишите,-сколько-обычно-занимает-продажа.-Когда-можно-считать,-что-продажи-прошли-очень-быстро,-а-когда-необычно-долго?-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?</a></span></li><li><span><a href="#Уберите-редкие-и-выбивающиеся-значения.-Опишите,-какие-особенности-обнаружили." data-toc-modified-id="Уберите-редкие-и-выбивающиеся-значения.-Опишите,-какие-особенности-обнаружили.-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили.</a></span></li><li><span><a href="#Какие-факторы-больше-всего-влияют-на-стоимость-квартиры?-Изучите,-зависит-ли-цена-от-площади,-числа-комнат,-удалённости-от-центра.-Изучите-зависимость-цены-от-того,-на-каком-этаже-расположена-квартира:-первом,-последнем-или-другом.-Также-изучите-зависимость-от-даты-размещения:-дня-недели,-месяца-и-года." data-toc-modified-id="Какие-факторы-больше-всего-влияют-на-стоимость-квартиры?-Изучите,-зависит-ли-цена-от-площади,-числа-комнат,-удалённости-от-центра.-Изучите-зависимость-цены-от-того,-на-каком-этаже-расположена-квартира:-первом,-последнем-или-другом.-Также-изучите-зависимость-от-даты-размещения:-дня-недели,-месяца-и-года.-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от площади, числа комнат, удалённости от центра. Изучите зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом. Также изучите зависимость от даты размещения: дня недели, месяца и года.</a></span><ul class="toc-item"><li><span><a href="#Зависимость-цены-от-площади" data-toc-modified-id="Зависимость-цены-от-площади-4.4.1"><span class="toc-item-num">4.4.1&nbsp;&nbsp;</span>Зависимость цены от площади</a></span></li><li><span><a href="#Зависимость-от-количества-комнат" data-toc-modified-id="Зависимость-от-количества-комнат-4.4.2"><span class="toc-item-num">4.4.2&nbsp;&nbsp;</span>Зависимость от количества комнат</a></span></li><li><span><a href="#Зависимость-от-удаленности-от-центра" data-toc-modified-id="Зависимость-от-удаленности-от-центра-4.4.3"><span class="toc-item-num">4.4.3&nbsp;&nbsp;</span>Зависимость от удаленности от центра</a></span></li><li><span><a href="#Зависимость-цены-от-того,-на-каком-этаже-расположена-квартира:-первом,-последнем-или-другом" data-toc-modified-id="Зависимость-цены-от-того,-на-каком-этаже-расположена-квартира:-первом,-последнем-или-другом-4.4.4"><span class="toc-item-num">4.4.4&nbsp;&nbsp;</span>Зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом</a></span></li></ul></li><li><span><a href="#Изучите-зависимость-от-даты-размещения:-дня-недели,-месяца-и-года." data-toc-modified-id="Изучите-зависимость-от-даты-размещения:-дня-недели,-месяца-и-года.-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Изучите зависимость от даты размещения: дня недели, месяца и года.</a></span></li><li><span><a href="#Выберите-10-населённых-пунктов-с-наибольшим-числом-объявлений.-Посчитайте-среднюю-цену-квадратного-метра-в-этих-населённых-пунктах.-Выделите-среди-них-населённые-пункты-с-самой-высокой-и-низкой-стоимостью-жилья.-Эти-данные-можно-найти-по-имени-в-столбце-'locality_name'." data-toc-modified-id="Выберите-10-населённых-пунктов-с-наибольшим-числом-объявлений.-Посчитайте-среднюю-цену-квадратного-метра-в-этих-населённых-пунктах.-Выделите-среди-них-населённые-пункты-с-самой-высокой-и-низкой-стоимостью-жилья.-Эти-данные-можно-найти-по-имени-в-столбце-'locality_name'.-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите среди них населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце 'locality_name'.</a></span></li><li><span><a href="#Изучите-предложения-квартир:-для-каждой-квартиры-есть-информация-о-расстоянии-до-центра.-Выделите-квартиры-в-Санкт-Петербурге-('locality_name').-Ваша-задача-—-выяснить,-какая-область-входит-в-центр.-Создайте-столбец-с-расстоянием-до-центра-в-километрах:-округлите-до-целых-значений.-После-этого-посчитайте-среднюю-цену-для-каждого-километра.-Постройте-график:-он-должен-показывать,-как-цена-зависит-от-удалённости-от-центра.-Определите-границу,-где-график-сильно-меняется-—-это-и-будет-центральная-зона." data-toc-modified-id="Изучите-предложения-квартир:-для-каждой-квартиры-есть-информация-о-расстоянии-до-центра.-Выделите-квартиры-в-Санкт-Петербурге-('locality_name').-Ваша-задача-—-выяснить,-какая-область-входит-в-центр.-Создайте-столбец-с-расстоянием-до-центра-в-километрах:-округлите-до-целых-значений.-После-этого-посчитайте-среднюю-цену-для-каждого-километра.-Постройте-график:-он-должен-показывать,-как-цена-зависит-от-удалённости-от-центра.-Определите-границу,-где-график-сильно-меняется-—-это-и-будет-центральная-зона.-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге ('locality_name'). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона.</a></span></li><li><span><a href="#Выделите-сегмент-квартир-в-центре.-Проанализируйте-эту-территорию-и-изучите-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-Также-выделите-факторы,-которые-влияют-на-стоимость-квартиры-(число-комнат,-этаж,-удалённость-от-центра,-дата-размещения-объявления).-Сделайте-выводы.-Отличаются-ли-они-от-общих-выводов-по-всему-городу?" data-toc-modified-id="Выделите-сегмент-квартир-в-центре.-Проанализируйте-эту-территорию-и-изучите-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-Также-выделите-факторы,-которые-влияют-на-стоимость-квартиры-(число-комнат,-этаж,-удалённость-от-центра,-дата-размещения-объявления).-Сделайте-выводы.-Отличаются-ли-они-от-общих-выводов-по-всему-городу?-4.8"><span class="toc-item-num">4.8&nbsp;&nbsp;</span>Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всему городу?</a></span></li><li><span><a href="#Сравнение-центра-и-остального-Петербурга" data-toc-modified-id="Сравнение-центра-и-остального-Петербурга-4.9"><span class="toc-item-num">4.9&nbsp;&nbsp;</span>Сравнение центра и остального Петербурга</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекc Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# * Шаг 1. Откройте файл с данными и изучите общую информацию
# Путь к файлу: /datasets/real_estate_data.csv. Скачать датасет
#
# * Шаг 2. Предобработка данных
# определите и изучите пропущенные значения:
# для некоторых пропущенных значений можно предположить логичную замену. Например, если человек не указал число балконов — скорее всего, их нет. Такие пропуски правильно заменить на 0. Для других типов данных нет подходящего значения на замену. В этом случае правильно оставить эти значения пустыми. Отсутствие значения — тоже важный сигнал, который не нужно прятать;
# заполните пропуски, где это уместно. Опишите, почему вы решили заполнить пропуски именно в этих столбцах и как выбрали значения;
# укажите причины, которые могли привести к пропускам в данных.
# приведите данные к нужным типам:
# поясните, в каких столбцах нужно изменить тип данных и почему.
# * Шаг 3. Посчитайте и добавьте в таблицу:
# цену квадратного метра;
# день недели, месяц и год публикации объявления;
# этаж квартиры; варианты — первый, последний, другой;
# соотношение жилой и общей площади, а также отношение площади кухни к общей.
# * Шаг 4. Проведите исследовательский анализ данных и выполните инструкции:
# Изучите следующие параметры: площадь, цена, число комнат, высота потолков. Постройте гистограммы для каждого параметра.
# Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?
# Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили.
# Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от площади, числа комнат, удалённости от центра. Изучите зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом. Также изучите зависимость от даты размещения: дня недели, месяца и года.
# Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите среди них населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце 'locality_name'.
# Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге ('locality_name'). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона.
# Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всему городу?
# * Шаг 5. Напишите общий вывод
# Оформление: Выполните задание в Jupyter Notebook. Заполните программный код в ячейках типа code, текстовые пояснения — в ячейках типа markdown. Примените форматирование и заголовки.
#
# Описание данных
#
# airports_nearest — расстояние до ближайшего аэропорта в метрах (м)
# balcony — число балконов
# ceiling_height — высота потолков (м)
# cityCenters_nearest — расстояние до центра города (м)
# days_exposition — сколько дней было размещено объявление (от публикации до снятия)
# first_day_exposition — дата публикации
# floor — этаж
# floors_total — всего этажей в доме
# is_apartment — апартаменты (булев тип)
# kitchen_area — площадь кухни в квадратных метрах (м²)
# last_price — цена на момент снятия с публикации
# living_area — жилая площадь в квадратных метрах(м²)
# locality_name — название населённого пункта
# open_plan — свободная планировка (булев тип)
# parks_around3000 — число парков в радиусе 3 км
# parks_nearest — расстояние до ближайшего парка (м)
# ponds_around3000 — число водоёмов в радиусе 3 км
# ponds_nearest — расстояние до ближайшего водоёма (м)
# rooms — число комнат
# studio — квартира-студия (булев тип)
# total_area — площадь квартиры в квадратных метрах (м²)
# total_images — число фотографий квартиры в объявлении
#
# ======================================================================

# %% [markdown]
# Импортируем необходимые для исследования библиотеки.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display

# %% [markdown]
# Фрейм необходимый для нахождения дубликатов:

# %% [markdown]
# ## Изучение данных из файла

# %%
data = pd.read_csv("/datasets/real_estate_data.csv", sep="\t")
display(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %%
display(data.head(10))
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1             7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2            10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3             0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4             2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5            10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6             6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7             5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8            20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9            18   5400000.0       61.00  2017-02-26T00:00:00      3
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0        51.00      8          NaN  ...
# 1             NaN          11.0        18.60      1          NaN  ...
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# 1. total_images 23699 non-null int64 / не нужный столбец, отражающий количество фотографий в обьявлении
# 2. last_price 23699 non-null float64 / меняем тип данных
# 3. total_area 23699 non-null float64 / корректно
# 4. first_day_exposition 23699 non-null object / меняем тип данных
# 5. rooms 23699 non-null int64 / корректно
# 6. ceiling_height 14504 non-null float64 / много пропусков, заполним наиболее часто встречающимся значением
# 7. floors_total 23613 non-null float64 / нужен анализ совместно с количеством этажей, присутствуют пропуска
# 8. living_area 21796 non-null float64 / пропущенные занчения, необходимо изучить
# 9. floor 23699 non-null int64 / корректно
# 10. is_apartment 2775 non-null object / много пропущенных, скорее всего здесь 1/0
# 11. studio 23699 non-null bool / корректно
# 12. open_plan 23699 non-null bool / корректно
# 13. kitchen_area 21421 non-null float64 / пропуски, надо изучить
# 14. balcony 12180 non-null float64 / скорее всего история повторяется пропуски из-за 1/0
# 15. locality_name 23650 non-null object / пропусков мало, изучим и скорее всего удалим
# 16. airports_nearest 18157 non-null float64 / пропуски, постараемся заполнить и сменить данные на int
# 17. cityCenters_nearest 18180 non-n ull float64 / заполнить, тип данных int
# 18. parks_around3000 18181 non-null float64 / пропуски, надо изучить
# 19. parks_nearest 8079 non-null float64 / заполнить, тип данных int
# 20. ponds_around3000 18181 non-null float64 / пропуски, надо изучить и сменить тип данных на int
# 21. ponds_nearest 9110 non-null float64 / пропуски, надо тоже изучить, сменить тип данных на int и по возможности заполнить
# 22. days_exposition 20518 non-null float64 / необходим анализ и сменить тип данных на int

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Пропуски

# %% [markdown]
# #### total_images

# %%
display(data['total_images'].value_counts())
# Out:
# 10    1798
# 9     1725
# 20    1694
# 8     1585
# 7     1521
# 6     1482
# 11    1362
# 5     1301
# 12    1225
# 0     1059
# 13    1015
# 4      986
# 14     986
# 15     948
# 1      872
# 3      769
# 16     761
# 17     650
# 18     642
# 2      640
# 19     603
# 23      16
# 21      12
# 24       8
# 22       8
# 26       5
# 28       4
# 32       4
# 29       3
# 50       3
# 27       2
# 35       2
# 30       2
# 31       2
# 39       1
# 25       1
# 42       1
# 37       1
# Name: total_images, dtype: int64

# %% [markdown]
# Как уже отмечал ранее, не нужный столбец, отражающий кол-во фотографий. Данные при этом корректны.

# %% [markdown]
# #### last_price

# %% [markdown]
# Поменяем тип данных на int.

# %%
data['last_price'] = data['last_price'].astype(int)

# %% [markdown]
# Напишем функцию для дальнейшего описания данных, которая отобразит визуально данные на диаграмме.

# %%
def describing(target): 
    print(data[target].head(7), data[target].describe())
    data.boxplot(column=target, figsize=(3,7)); 
    plt.show()
    data[target].hist(figsize=(16,3), bins=100);

describing('last_price')
# Out:
# 0    13000000
# 1     3350000
# 2     5196000
# 3    64900000
# 4    10000000
# 5     2890000
# 6     3700000
# Name: last_price, dtype: int64 count    2.369900e+04
# mean     6.541549e+06
# std      1.088701e+07
# min      1.219000e+04
# 25%      3.400000e+06
# 50%      4.650000e+06
# 75%      6.800000e+06
# max      7.630000e+08
# Name: last_price, dtype: float64

# %% [markdown]
# График растянулся от 0 до 8. Поскольку цена не может быть 0 и не видно значений ближе к 8, вероятно там есть выбросы. Увеличим выбросы в диапазонах от нуля до миллиона и от 6 миллионов, до 8. Посмотрим "хвосты".

# %%
basket = 100
data.hist('last_price', bins=basket, figsize=(14,3), range=(0, 1000000));
data.hist('last_price', bins=basket, figsize=(14,3), range=(60000000, 800000000))
# Out:
# array([[<AxesSubplot:title={'center':'last_price'}>]], dtype=object)

# %% [markdown]
# Как и предполагалось, есть выбросы.
#
# Избавимся от выбросов. Оставим все что больше 400 тысяч и меньше 100 миллионов.

# %%
data = data.query('400000 < last_price < 100000000')
data.reset_index(inplace=True, drop=True)
print(data.index)
print(data['last_price'].describe())
# Out:
# RangeIndex(start=0, stop=23661, step=1)
# count    2.366100e+04
# mean     6.251771e+06
# std      6.424397e+06
# min      4.300000e+05
# 25%      3.400000e+06
# 50%      4.635000e+06
# 75%      6.750000e+06
# max      9.900000e+07
# Name: last_price, dtype: float64

# %% [markdown]
# Все впорядке. избавились от 38 позиций. Столбец готов для исследования.

# %% [markdown]
# #### total_area

# %%
describing('total_area')
# Out:
# 0    108.0
# 1     40.4
# 2     56.0
# 3    159.0
# 4    100.0
# 5     30.4
# 6     37.3
# Name: total_area, dtype: float64 count    23661.000000
# mean        59.925974
# std         33.470704
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.600000
# max        590.000000
# Name: total_area, dtype: float64

# %% [markdown]
# Увеличим гистограмму в районе выше 250 и до 600.

# %%
data.hist('total_area', bins=basket, figsize=(14,3), range=(250, 600))
# Out:
# array([[<AxesSubplot:title={'center':'total_area'}>]], dtype=object)

# %% [markdown]
# Визуально все нормально. Оставим как есть.

# %% [markdown]
# #### first_day_exposition

# %% [markdown]
# В столбце указана дата/время, приведем к соответствующему типу данных.

# %%
data['first_day_exposition'].head(5)
# Out:
# 0    2019-03-07T00:00:00
# 1    2018-12-04T00:00:00
# 2    2015-08-20T00:00:00
# 3    2015-07-24T00:00:00
# 4    2018-06-19T00:00:00
# Name: first_day_exposition, dtype: object

# %%
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')
data['first_day_exposition'].head(5)
# Out:
# 0   2019-03-07
# 1   2018-12-04
# 2   2015-08-20
# 3   2015-07-24
# 4   2018-06-19
# Name: first_day_exposition, dtype: datetime64[ns]

# %% [markdown]
# Все исправили, идём дальше.

# %% [markdown]
# #### rooms

# %%
describing('rooms')
# Out:
# 0    3
# 1    1
# 2    2
# 3    3
# 4    2
# 5    1
# 6    1
# Name: rooms, dtype: int64 count    23661.000000
# mean         2.065720
# std          1.069614
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         19.000000
# Name: rooms, dtype: float64

# %%
data['rooms'].value_counts()
# Out:
# 1     8047
# 2     7938
# 3     5810
# 4     1171
# 5      316
# 0      197
# 6      100
# 7       54
# 8       10
# 9        8
# 10       3
# 11       2
# 14       2
# 16       1
# 19       1
# 15       1
# Name: rooms, dtype: int64

# %% [markdown]
# 197 квартир с значением комнат - 0. Такое вряд-ли возможно, попробуем изучить эти строки по площадям.

# %%
data.query('rooms == 0')['total_area'].describe()
# Out:
# count    197.000000
# mean      29.279746
# std       25.855264
# min       15.500000
# 25%       24.050000
# 50%       26.050000
# 75%       28.400000
# max      371.000000
# Name: total_area, dtype: float64

# %% [markdown]
# 197 значений 0. При этом большинство значений менее 30 кв. метров.

# %% [markdown]
# Создадим функцию, которая распишет данные по "n" - комнатным квартирам.

# %%
for n in range(1,5):
    print(f'{n} комнатная квартира:',data.query('rooms == @n')['total_area'].describe())
    print()
# Out:
# 1 комнатная квартира: count    8047.000000
# mean       37.644669
# std         9.338358
# min        12.000000
# 25%        32.500000
# 50%        36.560000
# 75%        41.000000
# max       494.100000
# Name: total_area, dtype: float64
#
# 2 комнатная квартира: count    7938.000000
# mean       55.831810
# std        13.101427
# min        20.000000
# 25%        46.000000
# 50%        53.000000
# 75%        62.000000
# max       196.000000
# Name: total_area, dtype: float64
#
# 3 комнатная квартира: count    5810.000000
# mean       77.685761
# std        23.049603
# min        40.100000
# 25%        62.000000
# 50%        72.900000
# 75%        87.000000
# max       363.100000
# Name: total_area, dtype: float64
#
# 4 комнатная квартира: count    1171.000000
# mean      106.417848
# std        41.682949
# min        42.000000
# 25%        77.650000
# 50%        98.900000
# 75%       125.000000
# max       470.300000
# Name: total_area, dtype: float64

# %% [markdown]
# * все что менее 40 кв.м - сделаем 1 комнатными
# * от 40 до 60 кв.м - сделаем 2 комнатными
# * от 60 до 80 кв.м сделаем 3 комнатными
# * от 80 кв.м сделаем 4 комнатными

# %% [markdown]
# * 371 кв.м удалим, так как сложно понять сколько здесь комнат

# %% [markdown]
# Сохраним индексы где кол-во комнат равно 0. Для дальнейшей проверки.

# %%
zero_room = data[data['rooms']==0].index

# %%
data.loc[(data['rooms']==0) & (data['total_area']<40), 'rooms'] = 1
data.loc[(data['rooms']==0) & (data['total_area']>40) & (data['total_area']<60), 'rooms'] = 2
data.loc[(data['rooms']==0) & (data['total_area']>60) & (data['total_area']<80), 'rooms'] = 3
data.loc[(data['rooms']==0) & (data['total_area']>80) & (data['total_area']<130), 'rooms'] = 4

# %%
print("Кол-во строк перед удалением", data.shape, len(data))
data.drop(data.loc[(data['rooms']==0) & (data['total_area']==371)].index,inplace=True, axis=0)
print("Кол-во строк после удаления", data.shape, len(data))
# Out:
# Кол-во строк перед удалением (23661, 22) 23661
# Кол-во строк после удаления (23660, 22) 23660

# %% [markdown]
# Сбросим индексы после удаления.

# %%
data.reset_index(inplace=True, drop=True)
data.tail()
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 23655             9     9700000      133.81           2017-03-21      3
# 23656            14     3100000       59.00           2018-01-15      3
# 23657            18     2500000       56.70           2018-02-11      2
# 23658            13    11475000       76.75           2017-03-28      2
# 23659             4     1350000       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 23655             3.7           5.0         73.3      3          NaN  ...
# 23656             NaN           5.0         38.0      4          NaN  ...
# 23657             NaN           3.0         29.7      1          NaN  ...
# 23658             3.0          17.0          NaN     12          NaN  ...
# 23659             2.5           5.0         12.3      1          NaN  ...
#
#        kitchen_area  balcony        locality_name  airports_nearest  \
# ...

# %% [markdown]
# Строку удалили. Индексы сбросили.

# %% [markdown]
# #### ceiling_height

# %%
describing('ceiling_height')
# Out:
# 0    2.70
# 1     NaN
# 2     NaN
# 3     NaN
# 4    3.03
# 5     NaN
# 6     NaN
# Name: ceiling_height, dtype: float64 count    14477.000000
# mean         2.769807
# std          1.261218
# min          1.000000
# 25%          2.510000
# 50%          2.650000
# 75%          2.800000
# max        100.000000
# Name: ceiling_height, dtype: float64

# %%
data['ceiling_height'].value_counts()
# Out:
# 2.50     3515
# 2.60     1646
# 2.70     1574
# 3.00     1110
# 2.80      992
#          ...
# 22.60       1
# 3.76        1
# 5.20        1
# 2.89        1
# 4.65        1
# Name: ceiling_height, Length: 180, dtype: int64

# %% [markdown]
# Построим гистограмму для визуального отображения данных (начало, середина, конец).

# %%
data['ceiling_height'].hist(figsize=(12,3), bins=60, range=(0,2.3));
plt.show()
data['ceiling_height'].hist(figsize=(12,3), bins=60, range=(2.3, 4.5));
plt.show()
data['ceiling_height'].hist(figsize=(12,3), bins=60, range=(4.5,40));

# %%
display(data.query('ceiling_height > 19 and ceiling_height < 35'))
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 355              17     3600000        55.2           2018-07-12      2
# 3139             14     2900000        75.0           2018-11-12      3
# 4634              0     4300000        45.0           2018-02-01      2
# 4867              7     3000000        25.0           2017-09-27      1
# 5066              0     3850000        30.5           2018-10-03      1
# 5236              0     2500000        54.0           2017-10-13      2
# 5659              4     4400000        50.0           2017-08-08      2
# 5797             17     8150000        80.0           2019-01-09      2
# 6235              6     3300000        44.4           2019-03-25      2
# 9363              5     3950000        42.0           2017-03-26      3
# 10757             8     3800000        58.0           2017-10-13      2
# 11269             0     1950000        37.0           2019-03-20      1
# ...

# %% [markdown]
# Судя по срезу, это обычные квартиры. А высота потолков, можно предположить, получилась из-за неправильной запятой.
# Разделим эти значения на 10.

# %%
index_list_height = data.query('ceiling_height > 19 and ceiling_height < 35').index 
data.loc[index_list_height, 'ceiling_height'] = data.loc[index_list_height, 'ceiling_height'] / 10

# %%
data.loc[index_list_height]['ceiling_height']
# Out:
# 355      2.50
# 3139     3.20
# 4634     2.50
# 4867     2.70
# 5066     2.40
# 5236     2.70
# 5659     2.60
# 5797     2.70
# 6235     2.50
# 9363     2.50
# 10757    2.70
# 11269    2.50
# 14361    2.50
# 17469    2.00
# 17830    2.70
# 18517    2.50
# 20444    2.70
# 20473    2.26
# 21342    2.75
# 21789    2.70
# 22298    3.20
# 22899    2.70
# Name: ceiling_height, dtype: float64

# %%
data['ceiling_height'].tail(10)
# Out:
# 23650    2.86
# 23651     NaN
# 23652    2.75
# 23653     NaN
# 23654    2.60
# 23655    3.70
# 23656     NaN
# 23657     NaN
# 23658    3.00
# 23659    2.50
# Name: ceiling_height, dtype: float64

# %%
index_list = data.query('ceiling_height>35 or ceiling_height<2.4 or 7<ceiling_height<19').index
print(data.loc[index_list, 'ceiling_height'])
# Out:
# 227        2.34
# 552        2.00
# 1577       2.30
# 2564       2.00
# 3465       8.00
# 4203       2.00
# 5488       2.30
# 5702       1.20
# 5840       2.00
# 5853       8.30
# 11336      2.00
# 12738      2.20
# 15038     14.00
# 15719      8.00
# 16422      2.00
# 16857      2.00
# 16907      1.75
# 17415      8.00
# 17469      2.00
# 17735      2.30
# 17767      2.25
# 19070      2.00
# 19300      2.00
# 20473      2.26
# 20486      2.00
# 22271     10.30
# 22552      1.00
# 22830    100.00
# 22921      2.00
# 23459      2.30
# Name: ceiling_height, dtype: float64

# %%
print("Кол-во строк перед удалением", len(data))
data.drop(index_list, inplace=True, axis=0)
print("Кол-во строк после удаления", len(data))

data.reset_index(inplace=True, drop=True)
display(data.tail())
# Out:
# Кол-во строк перед удалением 23660
# Кол-во строк после удаления 23630
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 23625             9     9700000      133.81           2017-03-21      3
# 23626            14     3100000       59.00           2018-01-15      3
# 23627            18     2500000       56.70           2018-02-11      2
# 23628            13    11475000       76.75           2017-03-28      2
# 23629             4     1350000       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 23625             3.7           5.0         73.3      3          NaN  ...
# 23626             NaN           5.0         38.0      4          NaN  ...
# 23627             NaN           3.0         29.7      1          NaN  ...
# 23628             3.0          17.0          NaN     12          NaN  ...
# 23629             2.5           5.0         12.3      1          NaN  ...
#
# ...

# %%
data['ceiling_height'].describe()
# Out:
# count    14447.000000
# mean         2.725695
# std          0.273242
# min          2.400000
# 25%          2.520000
# 50%          2.650000
# 75%          2.800000
# max          5.800000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Для удобства работы с данными, переведем метры в сантиметры.

# %%
data['ceiling_height'] = data['ceiling_height'] * 100
data['ceiling_height'].describe()
# Out:
# count    14447.000000
# mean       272.569461
# std         27.324216
# min        240.000000
# 25%        252.000000
# 50%        265.000000
# 75%        280.000000
# max        580.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Переходим к проблеме с пропусками

# %%
data['ceiling_height'].isna().sum()
# Out:
# 9183

# %%
data['ceiling_height'].describe()
# Out:
# count    14447.000000
# mean       272.569461
# std         27.324216
# min        240.000000
# 25%        252.000000
# 50%        265.000000
# 75%        280.000000
# max        580.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Возьмем для заполнения столбца медианное значение 265.

# %%
data['ceiling_height'] = data['ceiling_height'].fillna(data['ceiling_height'].median())

# %%
print("Кол-во пропусков =", data['ceiling_height'].isna().sum())
# Out:
# Кол-во пропусков = 0

# %% [markdown]
# Осталось заменить тип данных на int.

# %%
data['ceiling_height'] = data['ceiling_height'].astype('int')
data['ceiling_height'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# Столбец готов.

# %% [markdown]
# #### floors_total

# %%
describing('floors_total')
# Out:
# 0    16.0
# 1    11.0
# 2     5.0
# 3    14.0
# 4    14.0
# 5    12.0
# 6    26.0
# Name: floors_total, dtype: float64 count    23544.000000
# mean        10.680683
# std          6.597606
# min          1.000000
# 25%          5.000000
# 50%          9.000000
# 75%         16.000000
# max         60.000000
# Name: floors_total, dtype: float64

# %%
data['floors_total'].value_counts()
# Out:
# 5.0     5770
# 9.0     3755
# 16.0    1373
# 12.0    1360
# 4.0     1195
# 10.0    1173
# 25.0    1073
# 6.0      907
# 17.0     831
# 3.0      667
# 7.0      583
# 14.0     551
# 18.0     504
# 24.0     469
# 8.0      386
# 2.0      380
# 15.0     364
# 23.0     352
# 19.0     339
# 22.0     286
# 20.0     271
# 13.0     229
# 11.0     203
# 27.0     164
# 21.0     158
# 26.0     124
# 35.0      24
# 1.0       24
# 28.0      21
# 36.0       3
# 29.0       1
# 60.0       1
# 52.0       1
# 34.0       1
# 33.0       1
# Name: floors_total, dtype: int64

# %%
display(data.query('floors_total.isna()').head())
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 186             12    11640000        65.2           2018-10-02      2
# 236              4     2438033        28.1           2016-11-23      1
# 456              4     9788348        70.8           2015-08-01      2
# 669              4     6051191        93.6           2017-04-06      3
# 1749             5     3600000        39.0           2017-04-22      1
#
#       ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 186              265           NaN        30.80      4          NaN  ...
# 236              265           NaN        20.75      1          NaN  ...
# 456              265           NaN        38.40     12          NaN  ...
# 669              265           NaN        47.10      8          NaN  ...
# 1749             265           NaN          NaN      9          NaN  ...
#
#       kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# Заполним пропуски в зависимости от столбца "floor" по такому плану(поскольку строк всего 86, то можно их заполнить любыми значениями, невыбивающимися из большинства. И на результат это мало повлияет):

# %% [markdown]
# * if floor = 1-5 то это 5-ти этажка (так как 5 и 9 этажки самые распространенные)
# * if floor = 6-9 то это 9-ти этажка (так как 5 и 9 этажки самые распространенные)
# * все что выше будем - приравняем floors_total к (floor-1) (так как если приравнять к первому или последнему это может повлиять на последующий анализ, пусть это будет не тот и не другой)

# %%
data.loc[data.query('floors_total.isna() and 1<=floor<=5').index, 'floors_total'] = 5
data.loc[data.query('floors_total.isna() and 6<=floor<=9').index, 'floors_total'] = 9
data.loc[data.query('floors_total.isna() and floor>9').index, 'floors_total'] = data['floor']-1
print('Строки с пропусками',
      data.query('floors_total.isna()'))
print(data['floors_total'].value_counts().head())
# Out:
# Строки с пропусками Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 22 columns]
# 5.0     5793
# 9.0     3784
# 16.0    1374
# 12.0    1363
# 4.0     1195
# Name: floors_total, dtype: int64

# %% [markdown]
# Меняем тип данных на int.

# %%
data['floors_total'] = data['floors_total'].astype('int')

# %%
data["floors_total"].count()
# Out:
# 23630

# %%
len(data)
# Out:
# 23630

# %%
data["floors_total"].dtype
# Out:
# dtype('int64')

# %% [markdown]
# #### living_area & kitchen_area

# %% [markdown]
# Сначала заполним "living_area" в студиях (если требуется)

# %%
print("Студий Всего",len(data.loc[data['studio']==True]))
print()
print("Студий с заполненными значениями", data.loc[data['studio']==True, 'living_area'].describe())
print(data['studio'].value_counts())
# Out:
# Студий Всего 149
#
# Студий с заполненными значениями count    139.000000
# mean      18.995396
# std        7.345598
# min        2.000000
# 25%       16.000000
# 50%       18.000000
# 75%       19.850000
# max       68.000000
# Name: living_area, dtype: float64
# False    23481
# True       149
# Name: studio, dtype: int64

# %% [markdown]
# Присутствует жилая площадь 2 кв. м. Вероятнее всего забыли дописать 0. Найдем эти студии и прибавим к значениям 10 метров.

# %%
index_list = data.loc[(data['living_area']<10) & (data['studio']==True), ['living_area', 'total_area']].index
print(data.loc[index_list, ['living_area', 'total_area']])
data.loc[(data['living_area']<10) & (data['studio']==True), 'living_area'] +=10 
print(data.loc[index_list, ['living_area', 'total_area']])
# Out:
#        living_area  total_area
# 17536          5.0        22.0
# 21698          2.0        23.0
#        living_area  total_area
# 17536         15.0        22.0
# 21698         12.0        23.0

# %% [markdown]
# Теперь в студиях значения площадей похожи на правду.
# Перейдем к пропускам и заполним их средними значениями.

# %%
print("Кол-во студий без пропуска =", data.loc[(data['living_area'].isna() == False) & (data['studio']==True), \
        'living_area'].count(), " // Кол-во студий =", data.loc[data['studio']==True, 'total_area'].count())
print()
avg_studio = data.loc[data['studio']==True, 'living_area'] / data.loc[data['studio']==True, 'total_area']
print(avg_studio.head())
print()

#убираем nan значения и ищем средний показатель жилой площади в студии
avg_studio = avg_studio.dropna().mean()
print("Средние показатели жилой площади в студии =", avg_studio)
print()

#производим замену умножив на долю жилой площади * общую площадь
data.loc[(data['living_area'].isna() == True) & (data['studio']==True), 'living_area'] = \
    data.loc[(data['living_area'].isna() == True) & (data['studio']==True), 'total_area'] * avg_studio
# Out:
# Кол-во студий без пропуска = 139  // Кол-во студий = 149
#
# 144    0.574074
# 439    0.912947
# 606         NaN
# 695    0.726141
# 714    0.705882
# dtype: float64
#
# Средние показатели жилой площади в студии = 0.6879269478769845

# %% [markdown]
# Теперь необходимо проверить, правильно ли мы заменили значения.

# %%
print("Кол-во студий со значением =", data.loc[(data['living_area'].isna() == False) & (data['studio']==True), \
        'living_area'].count(), " // Кол-во студий всего =", len(data.loc[data['studio']==True]))

display(data.query('studio==True'))
# Out:
# Кол-во студий со значением = 149  // Кол-во студий всего = 149
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 144               1     2450000       27.00           2017-03-30      1
# 439               8     2480000       27.11           2018-03-12      1
# 606               2     1850000       25.00           2019-02-20      1
# 695              12     2500000       24.10           2017-12-01      1
# 714               5     1500000       17.00           2017-06-07      1
# ...             ...         ...         ...                  ...    ...
# 22801             8     3090000       30.00           2017-12-17      1
# 22810             2     4280000       28.00           2017-10-26      1
# 23142             7     3200000       26.00           2017-09-01      1
# 23485            15     3350000       26.00           2018-09-07      1
# 23568             8     2350000       26.00           2018-06-26      1
#
# ...

# %% [markdown]
# Теперь необходимо заполнить остальные значения не относящиеся к студиям. Логично предположить что, чем больше общая площадь, тем больше площадь жилая и кухни, и тем больше доля другой(нежилой площади).
# Построим гистограмму зависимости living_area/total_area и на будущее тоже самое сделаем для кухни.

# %% [markdown]
# Рассмотрим общую, жилую и кухонную площадь вместе, так как они взаимосвязаны.

# %%
display(data.loc[:,['total_area', 'living_area', 'kitchen_area']])
# Out:
#        total_area  living_area  kitchen_area
# 0          108.00         51.0         25.00
# 1           40.40         18.6         11.00
# 2           56.00         34.3          8.30
# 3          159.00          NaN           NaN
# 4          100.00         32.0         41.00
# ...           ...          ...           ...
# 23625      133.81         73.3         13.83
# 23626       59.00         38.0          8.50
# 23627       56.70         29.7           NaN
# 23628       76.75          NaN         23.30
# 23629       32.30         12.3          9.00
#
# [23630 rows x 3 columns]

# %% [markdown]
# Посчитаем количество значений в каждом столбце.

# %%
print("Кол-во квартир всего (без студий) =", len(data.loc[data['studio']==False]))
# Out:
# Кол-во квартир всего (без студий) = 23481

# %%
print("Кол-во квартир с жилой площадью (без студий) =", data.loc[(data['living_area'].isna() == False) & \
                                              (data['studio']==False), 'living_area'].count(), )
# Out:
# Кол-во квартир с жилой площадью (без студий) = 21597

# %%
print("Кол-во квартир с кухней (без студий) =", data.loc[(data['kitchen_area'].isna() == False) & \
                                                        (data['studio']==False), 'kitchen_area'].count(), )
# Out:
# Кол-во квартир с кухней (без студий) = 21364

# %% [markdown]
# Сделаем срез датафрейма для дальнейшего сравнения

# %%
cut = pd.DataFrame(columns=['all','living', 'kitchen']) 
cut['all'] = data.loc[(data['total_area'].isna() == False) & (data['studio']==False), 'total_area']
cut['living'] = data.loc[(data['living_area'].isna() == False) & (data['studio']==False), 'living_area']
cut['kitchen'] = data.loc[(data['kitchen_area'].isna() == False) & (data['studio']==False), 'kitchen_area']
print(cut)
# Out:
#           all  living  kitchen
# 0      108.00    51.0    25.00
# 1       40.40    18.6    11.00
# 2       56.00    34.3     8.30
# 3      159.00     NaN      NaN
# 4      100.00    32.0    41.00
# ...       ...     ...      ...
# 23625  133.81    73.3    13.83
# 23626   59.00    38.0     8.50
# 23627   56.70    29.7      NaN
# 23628   76.75     NaN    23.30
# 23629   32.30    12.3     9.00
#
# [23481 rows x 3 columns]

# %%
part_kit = cut['kitchen'] / cut['all']
part_kit_median = part_kit.dropna().median()
print("part_kit_median =", part_kit_median)
print()
part_liv = cut['living'] / cut['all']
part_liv_median = part_liv.dropna().median()
print("part_liv_median =", part_liv_median)
# Out:
# part_kit_median = 0.1724137931034483
#
# part_liv_median = 0.5671641791044776

# %% [markdown]
# Теперь вычислим долю оставшихся площадей. Вычитая долю кухни и жилой площади.

# %%
part_kit = part_kit_median
part_liv = part_liv_median
part_other = 1 - part_liv_median - part_kit_median
print('part_other =',part_other)
# Out:
# part_other = 0.26042202779207413

# %% [markdown]
# Теперь необходимо заполнить умножая полученные значения доли на общую площадь.

# %%
# начнем с кухни
index_nan_kitchen = data.loc[(data['kitchen_area'].isna() == True) & (data['studio']==False)].index 
# получили нужные индексы с пропущенными значениями 'kitchen_area'
data.loc[index_nan_kitchen, 'kitchen_area'] = part_kit * data.loc[index_nan_kitchen, 'total_area']
#смотрим описание столбца с кухнями
data['kitchen_area'].describe()
# Out:
# count    23481.000000
# mean        10.476007
# std          5.821482
# min          1.300000
# 25%          7.000000
# 50%          9.000000
# 75%         12.000000
# max        107.000000
# Name: kitchen_area, dtype: float64

# %% [markdown]
# Проделываем тоже самое с жилыми помещениями.

# %%
index_nan_living = data.loc[(data['living_area'].isna() == True) & (data['studio']==False)].index 
#получили нужные индексы с пропущенными значениями 'living_area'
data.loc[index_nan_living, 'living_area'] = part_liv * data.loc[index_nan_living, 'total_area']
#смотрим описание столбца с жилыми помещениями
data['living_area'].describe()
# Out:
# count    23630.000000
# mean        34.342238
# std         21.288284
# min          2.000000
# 25%         19.000000
# 50%         30.000000
# 75%         42.000000
# max        409.000000
# Name: living_area, dtype: float64

# %%
counter = 0

def total_area_change():
    if data['total_area'] < data['kitchen_area'] + data['living_area']:
        return data['total_area'] == data['kitchen_area'] + data['living_area']
        counter += 1

    
total_area_change
print(counter)
# Out:
# 0

# %% [markdown]
# Видно что присутствуют как очень маленькие, так и очень большие значения.
# Установим разумные рамки для жилых помещений и для кухонь от 3 до 40. Все что выходит за рамки, приведем к максимально допустимым значениям.

# %%
min_kit = 3
max_kit = 40

data.loc[(data['kitchen_area']<min_kit) & (data['studio']==False), 'kitchen_area'] = min_kit
data.loc[(data['kitchen_area']>max_kit) & (data['studio']==False), 'kitchen_area'] = max_kit

data.loc[(data['studio']==False),'kitchen_area'].describe()
# Out:
# count    23481.000000
# mean        10.408837
# std          5.296227
# min          3.000000
# 25%          7.000000
# 50%          9.000000
# 75%         12.000000
# max         40.000000
# Name: kitchen_area, dtype: float64

# %% [markdown]
# Теперь смотрим на living_area

# %%
data.loc[(data['studio']==False),'total_area'].describe()
# Out:
# count    23481.000000
# mean        60.130972
# std         33.423512
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         70.000000
# max        590.000000
# Name: total_area, dtype: float64

# %% [markdown]
# Напомним что медиана была 56,7%

# %% [markdown]
# Малыми площадями будем считать если они меньше 30% от общей

# %% [markdown]
# Заполним эти значения на 30% (~середина между общ-56,7% и нежил-26.6%) от общей площадей.
# Также установим минимальный размер жилой площади = 5 кв.м (уж меньше некуда)
# И еще сделаем корректировку для квартир с общей площадью < 140 кв.м (там где площадь больше чем 140, там более менее сносные значения, и в них сильно будут отличаться от средней пропорции жилой/нежилой/кухни)

# %%
ind_lst = data.loc[ (data['living_area'] < data['total_area']*0.3) & (data['total_area']<140) & (data['studio']==False) ].index
data.loc[ind_lst, 'living_area'] = data.loc[ind_lst, 'total_area'] * 0.3

# %% [markdown]
# Проверяем

# %%
print(data['living_area'].describe())
data[(data['studio']==False)].plot(
    y='living_area', x='total_area', kind='scatter', figsize=(18,6), grid=True, xlim=(0, 150), ylim=(0, 150));
# Out:
# count    23630.000000
# mean        34.361226
# std         21.273457
# min          7.373134
# 25%         19.000000
# 50%         30.000000
# 75%         42.000000
# max        409.000000
# Name: living_area, dtype: float64

# %% [markdown]
# Теперь проверим корректность проделанного. Сверим оставшиеся помещения - другие (нежилые = общая - жилая - кухня) с разумным минимумом равным 4 кв.м (коридор=1,5 + (туалет+ванна)=2,5 = 4). Итого в самой маленькой квартире 12кв.м = 3кух + 5жил + 4нежил Минимум 7,37 - по минимуму проходим. (зато по общей площади теперь переполнение) Вспомним и запишем минимумы:
#
# kit_min = 3
# liv_min = 5
# noliv_min = 4

# %%
kit_min = 3
liv_min = 5
noliv_min = 4

# Индексы где другая (нежилая) площадь меньше noliv_min
ind_small_noliv = data.loc[ (data['studio']==False) & (((data['total_area'] - data['living_area'] - \
                                                        data['kitchen_area']) < noliv_min) )].index
display(data.loc[ind_small_noliv,['total_area', 'living_area','kitchen_area']])

# Выводим значения со слишком маленькой нежилой площадью
square_table = data.loc[ind_small_noliv,'total_area'] - data.loc[ind_small_noliv,'living_area'] - \
data.loc[ind_small_noliv,'kitchen_area']
print(square_table)
square_table.describe()
# Out:
#        total_area  living_area  kitchen_area
# 41           74.0        59.00     12.000000
# 171          49.0        38.00     10.000000
# 184          30.2        26.10      6.200000
# 220          37.0        28.00      9.000000
# 236          28.1        20.75      4.844828
# ...           ...          ...           ...
# 23229        48.2        42.20      6.000000
# 23510        24.8        18.00      4.275862
# 23541        29.0        18.60      6.600000
# 23542        37.0        25.00      8.020000
# 23611        59.0        52.00      7.000000
#
# [479 rows x 3 columns]
# 41       3.000000
# 171      1.000000
# 184     -2.100000
# 220      0.000000
# 236      2.505172
#            ...
# 23229    0.000000
# 23510    2.524138
# 23541    3.800000
# 23542    3.980000
# 23611    0.000000
# Length: 479, dtype: float64
# count    479.000000
# mean       0.347553
# std        3.928797
# min      -26.400000
# 25%        0.000000
# 50%        1.200000
# 75%        2.887931
# ...

# %% [markdown]
# Всплыли отрицательные значения.

# %% [markdown]
# Восполним остальную площадь до минимума (5кв.м) за счет жилой и кухни. Будем урезать каждую на 2%, пока пока не будут достигнуты минимумы или другая(нежилая) станет около 5 кв.м
# Напишем функцию cut_square(ind) которая будет принимать индекс некорректной строки и "подрезать" площади, если удачно возвращает 0 если нет ind

# %%
def cut_square(ind):
    kit = data.loc[ind, 'kitchen_area']
    liv = data.loc[ind, 'living_area']
    tot = data.loc[ind, 'total_area']
    kit_min = 3
    liv_min = 5
    noliv_min = 4
    cut = 0.98 # Коэффициент на который надо умножить чтобы обрезать значение на 2%
    while noliv_min >= tot - kit - liv:
        if liv > liv_min:
            liv = liv * cut  # Обрезаем на 2% жилую
        if kit > kit_min:
            kit = kit * cut  # Обрезаем на 2% кухню
        
    noliv = tot - kit - liv    
    data.loc[ind, 'kitchen_area'] = kit
    data.loc[ind, 'living_area'] = liv
    return [ind, tot, liv, kit, noliv]
    
# ------------------------------------    

# i = []
c=0 # Счетчик замен
for index in ind_small_noliv:
    c+=1
print("Произведенено замен =",c)
# Out:
# Произведенено замен = 479

# %%
square_table = data.loc[ind_small_noliv,'total_area'] - data.loc[ind_small_noliv,'living_area'] - \
data.loc[ind_small_noliv,'kitchen_area']
data.loc[:,['total_area','living_area','kitchen_area']].describe()
# Out:
#          total_area   living_area  kitchen_area
# count  23630.000000  23630.000000  23481.000000
# mean      59.927002     34.361226     10.408837
# std       33.424337     21.273457      5.296227
# min       12.000000      7.373134      3.000000
# 25%       40.000000     19.000000      7.000000
# 50%       52.000000     30.000000      9.000000
# 75%       69.600000     42.000000     12.000000
# max      590.000000    409.000000     40.000000

# %% [markdown]
# Все получилось. Минимальные значения комнаты ~7, кухни ~3.

# %% [markdown]
# Теперь округлим значения до 0.1

# %%
data[['living_area', 'kitchen_area']] = round(data[['living_area', 'kitchen_area']],1)
data[['living_area', 'kitchen_area']].head(3)
# Out:
#    living_area  kitchen_area
# 0         51.0          25.0
# 1         18.6          11.0
# 2         34.3           8.3

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23630 entries, 0 to 23629
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23630 non-null  int64
#  1   last_price            23630 non-null  int64
#  2   total_area            23630 non-null  float64
#  3   first_day_exposition  23630 non-null  datetime64[ns]
#  4   rooms                 23630 non-null  int64
#  5   ceiling_height        23630 non-null  int64
#  6   floors_total          23630 non-null  int64
#  7   living_area           23630 non-null  float64
#  8   floor                 23630 non-null  int64
#  9   is_apartment          2765 non-null   object
#  10  studio                23630 non-null  bool
#  11  open_plan             23630 non-null  bool
#  12  kitchen_area          23481 non-null  float64
#  13  balcony               12144 non-null  float64
#  14  locality_name         23581 non-null  object
# ...

# %% [markdown]
# Все впорядке. Надо помнить что кухонь меньше из-за наличия квартир-студий. В пропущенных значениях будет стоять nan.

# %% [markdown]
# #### floor

# %%
data['floor'].value_counts().tail(20)
# Out:
# 15    342
# 14    335
# 16    315
# 17    227
# 18    178
# 19    147
# 21    125
# 22    113
# 20    110
# 23    100
# 24     63
# 25     44
# 26     24
# 27     10
# 28      1
# 29      1
# 32      1
# 30      1
# 33      1
# 31      1
# Name: floor, dtype: int64

# %% [markdown]
# В столбце все впорядке. последний этаж 31.

# %% [markdown]
# #### is_apartment

# %% [markdown]
# Здесь скорее всего булевы значения. Пропуски надо будет заполнить 0. Проверим.

# %%
print(data['is_apartment'].value_counts(), data['is_apartment'].dtype)
# Out:
# False    2716
# True       49
# Name: is_apartment, dtype: int64 object

# %%
data.loc[data['is_apartment'] != True, 'is_apartment'] = False
data['is_apartment'] = data['is_apartment'].astype('bool')
print(data['is_apartment'].value_counts(), " // Тип = ", data['is_apartment'].dtype)
# Out:
# False    23581
# True        49
# Name: is_apartment, dtype: int64  // Тип =  bool

# %% [markdown]
# Все впорядке. Заполнили True/False.

# %% [markdown]
# #### studio

# %% [markdown]
# На первый взгляд все впорядке, проверим.

# %%
print(data['studio'].value_counts(), " // Тип = ", data['studio'].dtype)
# Out:
# False    23481
# True       149
# Name: studio, dtype: int64  // Тип =  bool

# %% [markdown]
# Количество студий рассчитывали ранее. Их было 149. Все корректно.

# %% [markdown]
# #### open_plan

# %%
data['open_plan'].value_counts()
# Out:
# False    23564
# True        66
# Name: open_plan, dtype: int64

# %% [markdown]
# Все впорядке.

# %% [markdown]
# #### balcony

# %%
print(data['balcony'].value_counts())
# Out:
# 1.0    4183
# 0.0    3745
# 2.0    3652
# 5.0     301
# 4.0     183
# 3.0      80
# Name: balcony, dtype: int64

# %%
print("Кол-во NaN =",data['balcony'].isna().sum())
# Out:
# Кол-во NaN = 11486

# %% [markdown]
# Предположим что у тех у кого NaN, отсуствуют балконы.

# %%
data['balcony'] = data['balcony'].fillna(0)
print(data['balcony'].value_counts())
print("Кол-во NaN =",data['balcony'].isna().sum())
# Out:
# 0.0    15231
# 1.0     4183
# 2.0     3652
# 5.0      301
# 4.0      183
# 3.0       80
# Name: balcony, dtype: int64
# Кол-во NaN = 0

# %% [markdown]
# Готово.

# %% [markdown]
# #### locality_name

# %%
print(data['locality_name'].value_counts())
print()
print("Кол-во пропущеных значений", data['locality_name'].isna().sum())
print()
display(data['locality_name'].sort_values().unique())
# Out:
# Санкт-Петербург                          15670
# посёлок Мурино                             522
# посёлок Шушары                             440
# Всеволожск                                 397
# Пушкин                                     369
#                                          ...
# посёлок Высокоключевой                       1
# поселок городского типа Большая Ижора        1
# деревня Каськово                             1
# деревня Вахнова Кара                         1
# поселок Гончарово                            1
# Name: locality_name, Length: 364, dtype: int64
#
# Кол-во пропущеных значений 49
# array(['Бокситогорск', 'Волосово', 'Волхов', 'Всеволожск', 'Выборг',
#        'Высоцк', 'Гатчина', 'Зеленогорск', 'Ивангород', 'Каменногорск',
#        'Кингисепп', 'Кириши', 'Кировск', 'Колпино', 'Коммунар',
#        'Красное Село', 'Кронштадт', 'Кудрово', 'Лодейное Поле',
#        'Ломоносов', 'Луга', 'Любань', 'Мурино', 'Никольское',
# ...

# %% [markdown]
# Дубликаты из-за Ё и Е. Также имеются пропуски.

# %% [markdown]
# Произведем замену Ё на Е.

# %%
# Чтобы не мучиться, заменим все "ё" на "е" во всем столбце 'locality_name'
import re
i = 0 # счетчик строк где Ё и ё
# for ind_str in data.loc[(data['locality_name']!=np.nan),'locality_name'].index:
for ind_str in data.loc[(data['locality_name'].isna()==False),'locality_name'].index:    
    loc_str = data.loc[ind_str, 'locality_name']
    if ('ё' or 'Ё') in loc_str:
#         print(loc_str)
        i+=1
        loc_str = re.sub('ё', 'е', loc_str)
        loc_str = re.sub('Ё', 'Е', loc_str)
#         print(loc_str)
    data.loc[ind_str, 'locality_name'] = loc_str
#     print(data.loc[ind_str, 'locality_name'])
print()
print("Кол-во строк где произведена замена =", i)
# Out:
# Кол-во строк где произведена замена = 2143

# %%
print(data['locality_name'].value_counts())
# Out:
# Санкт-Петербург              15670
# поселок Мурино                 556
# поселок Шушары                 440
# Всеволожск                     397
# Пушкин                         369
#                              ...
# деревня Меньково                 1
# деревня Лаврики                  1
# поселок Плоское                  1
# коттеджный поселок Лесное        1
# деревня Раздолье                 1
# Name: locality_name, Length: 330, dtype: int64

# %% [markdown]
# Замену произвели.
# Теперь сделаем лемматизацию, чтобы найти похожие по написанию значения.

# %%
from pymystem3 import Mystem 
m = Mystem()

#   Создадим и заполним ДатаФрейм где 3 столбца : 
#   'original' - оригинал строки, 'lemm' - Лемматизированная строка, 
#   'name' - лемматизированное имя населенного пункта
loc_df = pd.DataFrame(columns=['original', 'lemm', 'name'])
loc_df['original'] = data.loc[(data['locality_name'].isna()==False),'locality_name'].sort_values(na_position='last').unique()

for ind in loc_df.index:
    lem_str = m.lemmatize(loc_df.loc[ind, 'original'])
    loc_df.loc[ind, 'lemm'] = lem_str
    loc_df.loc[ind, 'name'] = lem_str[-2]

display(loc_df)

print(loc_df['lemm'].value_counts())
# Out:
#                  original                                 lemm          name
# 0            Бокситогорск                   [бокситогорск, \n]  бокситогорск
# 1                Волосово                       [волосово, \n]      волосово
# 2                  Волхов                         [волхов, \n]        волхов
# 3              Всеволожск                     [всеволожск, \n]    всеволожск
# 4                  Выборг                         [выборг, \n]        выборг
# ..                    ...                                  ...           ...
# 325         село Путилово             [село,  , путиловый, \n]     путиловый
# 326      село Рождествено           [село,  , рождествено, \n]   рождествено
# 327  село Русско-Высоцкое  [село,  , русский, -, высоцкий, \n]      высоцкий
# 328    село Старая Ладога     [село,  , старый,  , ладога, \n]        ладога
# 329              село Шум                   [село,  , шум, \n]           шум
#
# [330 rows x 3 columns]
# ...

# %% [markdown]
# Поселок саперный повторяется 2 раза.
# Найдем их из списка.

# %%
display(loc_df[loc_df['name']=='саперный'])
# Out:
#              original                        lemm      name
# 247  поселок Саперное  [поселок,  , саперный, \n]  саперный
# 248  поселок Саперный  [поселок,  , саперный, \n]  саперный

# %% [markdown]
# 2 разных населенных пункта. Находятся в лен области, оставим их без изменения.

# %%
print(loc_df['name'].value_counts())
# Out:
# бор          6
# павлово      3
# ижора        3
# колпана      2
# рахья        2
#             ..
# угловый      1
# девяткино    1
# семрино      1
# житковый     1
# сельцо       1
# Name: name, Length: 290, dtype: int64

# %% [markdown]
# Всего значений было 330. Есть повторяющиеся.

# %%
repeated = loc_df['name'].value_counts() # Series где запишем что и сколько повторяется

for name in repeated.index:
    if repeated[name] == 1:
        break
    loc_df[loc_df['name']==name]['original']

# %% [markdown]
# Заменим все городские поселки на поселок городского типа.

# %%
for ind_str in loc_df.loc[(loc_df['original'].isna()==False),'original'].index:    
    loc_str = loc_df.loc[ind_str, 'original']
    if 'городской поселок' in loc_str:
        print(loc_str)
        loc_str = re.sub('городской поселок', 'поселок городского типа', loc_str)
        i+=1
        loc_df.loc[ind_str, 'original'] = loc_str
print("Заменено:", i)
# Out:
# городской поселок Большая Ижора
# городской поселок Будогощь
# городской поселок Виллози
# городской поселок Лесогорский
# городской поселок Мга
# городской поселок Назия
# городской поселок Новоселье
# городской поселок Павлово
# городской поселок Рощино
# городской поселок Свирьстрой
# городской поселок Советский
# городской поселок Федоровское
# городской поселок Янино-1
# Заменено: 2156

# %%
i = 0 

for ind_str in data.loc[(data['locality_name'].isna()==False),'locality_name'].index:    
    loc_str = data.loc[ind_str, 'locality_name']
    if 'городской поселок' in loc_str:
        print(loc_str)
        loc_str = re.sub('городской поселок', 'поселок городского типа', loc_str)
        i+=1
        data.loc[ind_str, 'locality_name'] = loc_str
print("Заменено:", i)
# Out:
# городской поселок Янино-1
# городской поселок Янино-1
# городской поселок Янино-1
# городской поселок Янино-1
# городской поселок Большая Ижора
# городской поселок Янино-1
# городской поселок Павлово
# городской поселок Лесогорский
# городской поселок Янино-1
# городской поселок Большая Ижора
# городской поселок Новоселье
# городской поселок Федоровское
# городской поселок Янино-1
# городской поселок Янино-1
# городской поселок Мга
# городской поселок Янино-1
# городской поселок Новоселье
# городской поселок Новоселье
# городской поселок Назия
# городской поселок Павлово
# городской поселок Большая Ижора
# городской поселок Янино-1
# городской поселок Новоселье
# городской поселок Янино-1
# городской поселок Новоселье
# городской поселок Янино-1
# городской поселок Новоселье
# городской поселок Мга
# городской поселок Большая Ижора
# городской поселок Янино-1
# городской поселок Янино-1
# городской поселок Назия
# городской поселок Янино-1
# городской поселок Янино-1
# ...

# %%
loc_df = pd.DataFrame(columns=['original', 'lemm', 'name'], data=[])
loc_df['original'] = data.loc[(data['locality_name'].isna()==False),'locality_name'].sort_values().unique()
for ind in loc_df.index:
    lem_str = m.lemmatize(loc_df.loc[ind, 'original'])
    loc_df.loc[ind, 'lemm'] = lem_str
    loc_df.loc[ind, 'name'] = lem_str[-2]
display(loc_df.tail())
# Out:
#                  original                                 lemm         name
# 318         село Путилово             [село,  , путиловый, \n]    путиловый
# 319      село Рождествено           [село,  , рождествено, \n]  рождествено
# 320  село Русско-Высоцкое  [село,  , русский, -, высоцкий, \n]     высоцкий
# 321    село Старая Ладога     [село,  , старый,  , ладога, \n]       ладога
# 322              село Шум                   [село,  , шум, \n]          шум

# %%
print(loc_df['name'].value_counts())

rep_name = loc_df['name'].value_counts() # Series где запишем что и сколько повторяется

for name in rep_name.index:
    if rep_name[name] == 1:
        break
    print(loc_df[loc_df['name']==name]['original'])
# Out:
# бор           6
# рабитиц       2
# романовка     2
# кудрово       2
# павлово       2
#              ..
# лупполовый    1
# угловый       1
# девяткино     1
# семрино       1
# сельцо        1
# Name: name, Length: 290, dtype: int64
# 38                            Сосновый Бор
# 53                             деревня Бор
# 137                  деревня Трубников Бор
# 142                    деревня Чудской Бор
# 209          поселок Пансионат Зеленый Бор
# 275    поселок городского типа Красный Бор
# Name: original, dtype: object
# 114    деревня Рабитицы
# 228    поселок Рабитицы
# Name: original, dtype: object
# 90     деревня Малая Романовка
# 230          поселок Романовка
# Name: original, dtype: object
# 17            Кудрово
# 79    деревня Кудрово
# Name: original, dtype: object
# 284    поселок городского типа Павлово
# 316                       село Павлово
# Name: original, dtype: object
# 169            поселок Громово
# 304    поселок станции Громово
# ...

# %% [markdown]
# Исправим городской поселок, на поселок городского типа.

# %%
# Заменим все 'городской поселок' на 'поселок городского типа' в loc_df столбце 'original'

i = 0 # счетчик строк где 'городской поселок'
# for ind_str in loc_df.loc[(loc_df['locality_name']!=np.nan),'locality_name'].index:
for ind_str in loc_df.loc[(loc_df['original'].isna()==False),'original'].index:    
    loc_str = loc_df.loc[ind_str, 'original']
    if 'городской поселок' in loc_str:
        print(loc_str)
        loc_str = re.sub('городской поселок', 'поселок городского типа', loc_str)
        i+=1
#         print(loc_str)
        loc_df.loc[ind_str, 'original'] = loc_str
        print(loc_df.loc[ind_str, 'original'])
print("Кол-во строк где произведена замена =", i)
# Out:
# Кол-во строк где произведена замена = 0

# %%
i = 0 # счетчик строк где 'городской поселок'
# for ind_str in data.loc[(data['locality_name']!=np.nan),'locality_name'].index:
for ind_str in data.loc[(data['locality_name'].isna()==False),'locality_name'].index:    
    loc_str = data.loc[ind_str, 'locality_name']
    if 'городской поселок' in loc_str:
        print(loc_str)
        loc_str = re.sub('городской поселок', 'поселок городского типа', loc_str)
        i+=1
#         print(loc_str)
        data.loc[ind_str, 'locality_name'] = loc_str
print("Кол-во строк где произведена замена =", i)
# Out:
# Кол-во строк где произведена замена = 0

# %%
loc_df = pd.DataFrame(columns=['original', 'lemm', 'name'], data=[])
loc_df['original'] = data.loc[(data['locality_name'].isna()==False),'locality_name'].sort_values().unique()
for ind in loc_df.index:
    lem_str = m.lemmatize(loc_df.loc[ind, 'original'])
    loc_df.loc[ind, 'lemm'] = lem_str
    loc_df.loc[ind, 'name'] = lem_str[-2]
display(loc_df.tail())
# Out:
#                  original                                 lemm         name
# 318         село Путилово             [село,  , путиловый, \n]    путиловый
# 319      село Рождествено           [село,  , рождествено, \n]  рождествено
# 320  село Русско-Высоцкое  [село,  , русский, -, высоцкий, \n]     высоцкий
# 321    село Старая Ладога     [село,  , старый,  , ладога, \n]       ладога
# 322              село Шум                   [село,  , шум, \n]          шум

# %% [markdown]
# Посмотрим как дела обстоят с пропусками

# %% [markdown]
# Надо изучить расстояния которые даны, чтобы определить что это за населенный пункт

# %%
nan_loc_df = data.loc[data['locality_name'].isna()==True, ['cityCenters_nearest', 'airports_nearest', \
                                                           'parks_nearest', 'ponds_nearest']]
nan_loc_df.head()
# Out:
#       cityCenters_nearest  airports_nearest  parks_nearest  ponds_nearest
# 1093               4258.0           23478.0            NaN            NaN
# 2024                  NaN               NaN            NaN            NaN
# 2591              17369.0           22041.0            NaN          374.0
# 2620              17369.0           22041.0            NaN          374.0
# 3560               8127.0           27419.0            NaN          603.0

# %% [markdown]
# Удалим пропуски в 2 столбцах

# %%
nan_loc_df = nan_loc_df.dropna(subset=['cityCenters_nearest', 'airports_nearest'])
nan_loc_df['loc_list'] = np.nan
nan_loc_df
# Out:
#        cityCenters_nearest  airports_nearest  parks_nearest  ponds_nearest  \
# 1093                4258.0           23478.0            NaN            NaN
# 2591               17369.0           22041.0            NaN          374.0
# 2620               17369.0           22041.0            NaN          374.0
# 3560                8127.0           27419.0            NaN          603.0
# 4137                3902.0           25054.0          485.0          722.0
# 4175                3039.0           21774.0          690.0          953.0
# 4655                5382.0           26534.0          446.0          376.0
# 5327                9538.0           10556.0           67.0            NaN
# 5690               16788.0           21460.0            NaN          170.0
# 6744               17369.0           22041.0            NaN          374.0
# 7093                8582.0           14031.0            NaN            NaN
# ...

# %% [markdown]
# Будем искать похожие значения этой пары столбцов в строках датафрейма data где есть 'locality_name' с отклонением в +/-250м - delta (это значение подберем пробным путем) в столбцах cityCenters_nearest и airports_nearest.

# %%
loc_list=[] # сюда будет записываться locality_name (или множество из списка locality_name), которое совпадает(ют) по расстояниям
loc_dic = dict() # Словарь {индекс_пропущенного_значения : loc_list_совпавший_по_расстояниям_для_этого_индекса}
delta = 250 # отклонение в пределах которого искать
for i in nan_loc_df.index:
    a = nan_loc_df.loc[i, 'cityCenters_nearest'] #   Создадим для удобства,
    b = nan_loc_df.loc[i, 'airports_nearest']    #   чтобы не загромождать
    try:
        loc_list = data.query('( (@a-@delta) < cityCenters_nearest < (@a+@delta) ) and \
        ( (@b-@delta) < airports_nearest < (@b+@delta) )')['locality_name'] # .index
    except:
        loc_list = np.nan
#     print(loc_list)
    loc_dic[i] = set(loc_list)
#     input()   
# print(loc_dic)

# %%
for ind in nan_loc_df.index:
    print(ind, loc_dic[ind])
# Out:
# 1093 {nan, 'Санкт-Петербург'}
# 2591 {nan, 'Санкт-Петербург'}
# 2620 {nan, 'Санкт-Петербург'}
# 3560 {nan, 'Санкт-Петербург'}
# 4137 {nan, 'Санкт-Петербург'}
# 4175 {nan, 'Санкт-Петербург'}
# 4655 {nan, 'Санкт-Петербург'}
# 5327 {nan, 'Санкт-Петербург'}
# 5690 {nan, 'Санкт-Петербург'}
# 6744 {nan, 'Санкт-Петербург'}
# 7093 {nan, 'Санкт-Петербург'}
# 7309 {nan, 'Санкт-Петербург'}
# 7578 {nan, 'Санкт-Петербург'}
# 8544 {nan, 'Санкт-Петербург'}
# 8960 {nan, 'Павловск', 'Пушкин'}
# 9795 {nan, 'Санкт-Петербург'}
# 10096 {nan, 'Санкт-Петербург'}
# 11222 {nan, 'Санкт-Петербург'}
# 12849 {nan, 'Санкт-Петербург'}
# 12906 {nan, 'Санкт-Петербург'}
# 13192 {nan, 'Санкт-Петербург'}
# 13659 {nan, 'Санкт-Петербург'}
# 14240 {nan, 'Санкт-Петербург'}
# 15649 {nan, 'Санкт-Петербург'}
# 15828 {nan, 'Санкт-Петербург'}
# 16458 {nan, 'Санкт-Петербург'}
# 16520 {nan, 'Санкт-Петербург'}
# 16569 {nan, 'Санкт-Петербург'}
# 17717 {nan, 'Санкт-Петербург'}
# 18477 {nan, 'Санкт-Петербург'}
# ...

# %% [markdown]
# Хорошо видно , что по двум индексам совпала пара городов {'Пушкин', 'Павловск'}, одно значение не совпало - они нас не интересуют (их придется удалить).
# В совпавших - {'Санкт-Петербург'} - им то мы и заполним соответствующие пропуски.

# %%
for ind in nan_loc_df.index:
    if 'Санкт-Петербург' in loc_dic[ind]:
        data.loc[ind,'locality_name'] = 'Санкт-Петербург'
    print(ind, data.loc[ind,'locality_name'])
# Out:
# 1093 Санкт-Петербург
# 2591 Санкт-Петербург
# 2620 Санкт-Петербург
# 3560 Санкт-Петербург
# 4137 Санкт-Петербург
# 4175 Санкт-Петербург
# 4655 Санкт-Петербург
# 5327 Санкт-Петербург
# 5690 Санкт-Петербург
# 6744 Санкт-Петербург
# 7093 Санкт-Петербург
# 7309 Санкт-Петербург
# 7578 Санкт-Петербург
# 8544 Санкт-Петербург
# 8960 nan
# 9795 Санкт-Петербург
# 10096 Санкт-Петербург
# 11222 Санкт-Петербург
# 12849 Санкт-Петербург
# 12906 Санкт-Петербург
# 13192 Санкт-Петербург
# 13659 Санкт-Петербург
# 14240 Санкт-Петербург
# 15649 Санкт-Петербург
# 15828 Санкт-Петербург
# 16458 Санкт-Петербург
# 16520 Санкт-Петербург
# 16569 Санкт-Петербург
# 17717 Санкт-Петербург
# 18477 Санкт-Петербург
# 18868 Санкт-Петербург
# 18996 Санкт-Петербург
# 19917 Санкт-Петербург
# 20002 Санкт-Петербург
# 20595 Санкт-Петербург
# 21059 nan
# 21216 nan
# 21273 Санкт-Петербург
# 22410 Санкт-Петербург
# 22866 Санкт-Петербург
# 23146 Санкт-Петербург

# %% [markdown]
# Заполнили. Оставшиеся пропуски в data['locality_name'] удалим.

# %%
data['locality_name'].isna().sum()
# Out:
# 11

# %% [markdown]
# Удаляем и сбрасываем индекс.

# %%
data.dropna(subset = ['locality_name'], inplace=True)
data.reset_index(inplace=True, drop=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23619 entries, 0 to 23618
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23619 non-null  int64
#  1   last_price            23619 non-null  int64
#  2   total_area            23619 non-null  float64
#  3   first_day_exposition  23619 non-null  datetime64[ns]
#  4   rooms                 23619 non-null  int64
#  5   ceiling_height        23619 non-null  int64
#  6   floors_total          23619 non-null  int64
#  7   living_area           23619 non-null  float64
#  8   floor                 23619 non-null  int64
#  9   is_apartment          23619 non-null  bool
#  10  studio                23619 non-null  bool
#  11  open_plan             23619 non-null  bool
#  12  kitchen_area          23470 non-null  float64
#  13  balcony               23619 non-null  float64
#  14  locality_name         23619 non-null  object
# ...

# %% [markdown]
# Столбец готов к исследованию. Удалили всего 11 строк.

# %% [markdown]
# #### airports_nearest

# %% [markdown]
# Надо отметить , что количество значений в столбцах с 2 расстояниями и 2 некоторыми другими почти одинаковое - 18181:
#
# airports_nearest 18157 non-null float64 <br>
# cityCenters_nearest 18180 non-null float64 <br>
# parks_around3000 18181 non-null float64 <br>
# parks_nearest 8079 non-null float64 <br>
# ponds_around3000 18181 non-null float64 <br>
# ponds_nearest 9110 non-null float64 <br>

# %% [markdown]
# Заполнить данный столбец надо в зависимости от населенного пункта. По возможности средним значением.

# %%
describing('airports_nearest')
# Out:
# 0    18863.0
# 1    12817.0
# 2    21741.0
# 3    28098.0
# 4    31856.0
# 5        NaN
# 6    52996.0
# Name: airports_nearest, dtype: float64 count    18102.000000
# mean     28797.697879
# std      12642.490660
# min          0.000000
# 25%      18573.000000
# 50%      26737.000000
# 75%      37306.000000
# max      84869.000000
# Name: airports_nearest, dtype: float64

# %% [markdown]
# Выбросов не видно, зато наблюдаются нули.

# %%
data[data['airports_nearest']==0]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 21019             0     7000000        34.7           2018-09-23      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 21019             270             9         19.8      3         False  ...
#
#        kitchen_area  balcony    locality_name  airports_nearest  \
# 21019           6.0      2.0  Санкт-Петербург               0.0
#
#       cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 21019             22801.0               0.0            NaN               0.0
#
#        ponds_nearest  days_exposition
# 21019            NaN             60.0
#
# [1 rows x 22 columns]

# %%
data.loc[21003, 'airports_nearest'] = np.nan
data.loc[21003]
# Out:
# total_images                              7
# last_price                          4900000
# total_area                             49.0
# first_day_exposition    2018-02-01 00:00:00
# rooms                                     2
# ceiling_height                          300
# floors_total                              5
# living_area                            29.0
# floor                                     1
# is_apartment                          False
# studio                                False
# open_plan                             False
# kitchen_area                            8.0
# balcony                                 0.0
# locality_name               Санкт-Петербург
# airports_nearest                        NaN
# cityCenters_nearest                  8167.0
# parks_around3000                        0.0
# parks_nearest                           NaN
# ponds_around3000                        2.0
# ponds_nearest                         121.0
# ...

# %% [markdown]
# Все пропуски заполним медианами значений airports_nearest (если оно будет не NaN) из других строк где совпадает locality_name

# %%
print('Медианы расстояний airports_nearest в locality_name : ')
loc_median = data.groupby('locality_name')['airports_nearest'].median().sort_values()
loc_median = loc_median.dropna()
display(loc_median.head(15))

# Функция для присваивания пропуску значения медианы
def med_insert(loc_dist):
    if loc_dist not in loc_median:
        return np.nan
    return loc_median[loc_dist]


print('Проверка работы med_insert: поселок Понтонный - ', med_insert('поселок Понтонный')) 
print('Проверка работы med_insert: поселок Усть-Ижора - ', med_insert('поселок Усть-Ижора'))
# Out:
# Медианы расстояний airports_nearest в locality_name :
# locality_name
# поселок Александровская    12896.5
# Пушкин                     15766.0
# поселок Шушары             17427.0
# Павловск                   20529.5
# поселок Петро-Славянка     20605.0
# Красное Село               25717.0
# поселок Металлострой       25758.0
# Колпино                    26232.0
# поселок Усть-Ижора         26510.5
# Санкт-Петербург            26736.0
# поселок Стрельна           28317.0
# поселок Понтонный          30642.0
# поселок Саперный           34147.5
# Петергоф                   39231.0
# Ломоносов                  48415.5
# Name: airports_nearest, dtype: float64
# Проверка работы med_insert: поселок Понтонный -  30642.0
# Проверка работы med_insert: поселок Усть-Ижора -  26510.5

# %%
# Выборка для проверки
print('Всего пропущенных значений в столбце =', data['airports_nearest'].isna().sum())
test_ind = data.loc[(data['locality_name']=='Санкт-Петербург') & (data['airports_nearest'].isna()==True)].index
print("Всего пропущенных значений в Санкт-Петербург =", len(test_ind))
display(data.loc[test_ind,['locality_name','airports_nearest']].head(10))
# Out:
# Всего пропущенных значений в столбце = 5518
# Всего пропущенных значений в Санкт-Петербург = 85
#         locality_name  airports_nearest
# 81    Санкт-Петербург               NaN
# 591   Санкт-Петербург               NaN
# 602   Санкт-Петербург               NaN
# 731   Санкт-Петербург               NaN
# 740   Санкт-Петербург               NaN
# 792   Санкт-Петербург               NaN
# 971   Санкт-Петербург               NaN
# 1330  Санкт-Петербург               NaN
# 1864  Санкт-Петербург               NaN
# 1887  Санкт-Петербург               NaN

# %%
data.loc[data['airports_nearest'].isna()==True, 'airports_nearest'] = data['locality_name'].apply(med_insert)

# %% [markdown]
# Заменяем и проверяем.

# %%
display(data.loc[test_ind,['locality_name','airports_nearest']].head(10))
# Out:
#         locality_name  airports_nearest
# 81    Санкт-Петербург           26736.0
# 591   Санкт-Петербург           26736.0
# 602   Санкт-Петербург           26736.0
# 731   Санкт-Петербург           26736.0
# 740   Санкт-Петербург           26736.0
# 792   Санкт-Петербург           26736.0
# 971   Санкт-Петербург           26736.0
# 1330  Санкт-Петербург           26736.0
# 1864  Санкт-Петербург           26736.0
# 1887  Санкт-Петербург           26736.0

# %% [markdown]
# Теперь необходимо проверить сколько осталось пропусков.

# %%
data['airports_nearest'].isna().sum()
# Out:
# 4848

# %% [markdown]
# Искать аэропорты для всех населенных пунктов займет очень много времени. На исследования данный столбик не влияет. Оставим как есть.

# %% [markdown]
# #### cityCenters_nearest

# %%
describing('cityCenters_nearest')
# Out:
# 0    16028.0
# 1    18603.0
# 2    13933.0
# 3     6800.0
# 4     8098.0
# 5        NaN
# 6    19143.0
# Name: cityCenters_nearest, dtype: float64 count    18125.000000
# mean     14207.842041
# std       8603.229553
# min        181.000000
# 25%       9267.000000
# 50%      13114.000000
# 75%      16296.000000
# max      65968.000000
# Name: cityCenters_nearest, dtype: float64

# %% [markdown]
# Данные выглядят хорошо. Но надо разобраться с пропусками.

# %% [markdown]
# Заполняем медианами cityCenters_nearest не NaN и совпадает locality_name

# %%
print('Медианы расстояний cityCenters_nearest в locality_name : ')
loc_median = data.groupby('locality_name')['cityCenters_nearest'].median().sort_values()
loc_median = loc_median.dropna()
display(loc_median.head(15))

# Функция для присваивания пропуску значения медианы
def locality(loc_dist):
    if loc_dist not in loc_median:
        return np.nan
    return loc_median[loc_dist]


print('Проверка работы locality: поселок Песочный - ', locality('поселок Песочный')) 
print('Проверка работы locality: поселок Петро-Славянка - ', locality('поселок Петро-Славянка'))
# Out:
# Медианы расстояний cityCenters_nearest в locality_name :
# locality_name
# Санкт-Петербург            12247.5
# поселок Парголово          19311.0
# поселок Мурино             21888.0
# поселок Стрельна           23506.0
# поселок Шушары             24212.0
# поселок Левашово           25727.0
# поселок Песочный           26099.5
# поселок Петро-Славянка     27165.0
# поселок Александровская    27468.0
# поселок Металлострой       27619.0
# Пушкин                     27930.5
# поселок Усть-Ижора         28222.5
# поселок Лисий Нос          28226.0
# Красное Село               29142.0
# Колпино                    32018.0
# Name: cityCenters_nearest, dtype: float64
# Проверка работы locality: поселок Песочный -  26099.5
# Проверка работы locality: поселок Петро-Славянка -  27165.0

# %% [markdown]
# Применяем функцию

# %%
data.loc[data['cityCenters_nearest'].isna()==True, 'cityCenters_nearest'] = data['locality_name'].apply(med_insert)

# %% [markdown]
# Проверяем

# %%
display(data.loc[test_ind,['locality_name','cityCenters_nearest']].head(10))
# Out:
#         locality_name  cityCenters_nearest
# 81    Санкт-Петербург              12247.5
# 591   Санкт-Петербург              12247.5
# 602   Санкт-Петербург              12247.5
# 731   Санкт-Петербург              13355.0
# 740   Санкт-Петербург              12247.5
# 792   Санкт-Петербург              12247.5
# 971   Санкт-Петербург               9734.0
# 1330  Санкт-Петербург              12247.5
# 1864  Санкт-Петербург              12247.5
# 1887  Санкт-Петербург              12247.5

# %%
data['cityCenters_nearest'].isna().sum()
# Out:
# 4848

# %% [markdown]
# Пропусков всё ещё много.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23619 entries, 0 to 23618
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23619 non-null  int64
#  1   last_price            23619 non-null  int64
#  2   total_area            23619 non-null  float64
#  3   first_day_exposition  23619 non-null  datetime64[ns]
#  4   rooms                 23619 non-null  int64
#  5   ceiling_height        23619 non-null  int64
#  6   floors_total          23619 non-null  int64
#  7   living_area           23619 non-null  float64
#  8   floor                 23619 non-null  int64
#  9   is_apartment          23619 non-null  bool
#  10  studio                23619 non-null  bool
#  11  open_plan             23619 non-null  bool
#  12  kitchen_area          23470 non-null  float64
#  13  balcony               23619 non-null  float64
#  14  locality_name         23619 non-null  object
# ...

# %% [markdown]
# Есть вероятность что пропуски взаимосвязаны. Надо посмотреть их по строкам.

# %%
matches_False = data.query('airports_nearest.isna()==False and cityCenters_nearest.isna()==False and \
                                parks_around3000.isna()==False and ponds_around3000.isna()==False')

print('Все заполнен =', matches_False['locality_name'].count())
# Out:
# Все заполнен = 18126

# %%
matches_True = data.query('airports_nearest.isna()==True and cityCenters_nearest.isna()==True and \
                                parks_around3000.isna()==True and ponds_around3000.isna()==True')

print('Пропуск во всех 4х столбцах =', matches_True['locality_name'].count())
# Out:
# Пропуск во всех 4х столбцах = 4848

# %%
matches_True.groupby('locality_name')['locality_name'].count().sort_values().tail(15)
# Out:
# locality_name
# Коммунар                    89
# Никольское                  93
# Тосно                      103
# Кингисепп                  104
# Волхов                     111
# Сланцы                     112
# поселок Бугры              114
# Кириши                     125
# Сертолово                  142
# деревня Новое Девяткино    144
# Кудрово                    172
# Выборг                     235
# деревня Кудрово            299
# Гатчина                    307
# Всеволожск                 397
# Name: locality_name, dtype: int64

# %% [markdown]
# Взаимосвязь прослеживается. Вероятнее всего эти данные были не обязательны для заполнения. От сюда и вырисовывается такая картина. Не вижу вариантов как заполнить данные аккуратно. Оставим как есть. Столбец не должен повлиять на исследования.

# %% [markdown]
# #### parks_around3000

# %%
data['parks_around3000'].value_counts(dropna=False)
# Out:
# 0.0    10087
# 1.0     5667
# NaN     5493
# 2.0     1735
# 3.0      637
# Name: parks_around3000, dtype: int64

# %% [markdown]
# Здесь скорее всего не заполнен был пункт о наличии парков. Вероятнее всего они там отсутствуют. Поменяем NaN на 0.

# %%
data['parks_around3000'] = data['parks_around3000'].fillna(0)
display(data['parks_around3000'].value_counts(dropna=False))
data['parks_around3000'] = data['parks_around3000'].astype(int)
print(data['parks_around3000'].dtype)
# Out:
# 0.0    15580
# 1.0     5667
# 2.0     1735
# 3.0      637
# Name: parks_around3000, dtype: int64
# int64

# %% [markdown]
# NaN значений нет. Поехали дальше.

# %% [markdown]
# #### parks_nearest

# %% [markdown]
# Столбец не влияет на исследования. Если не получится быстро заполнить, оставим как есть.

# %%
describing('parks_nearest')
# Out:
# 0    482.0
# 1      NaN
# 2     90.0
# 3     84.0
# 4    112.0
# 5      NaN
# 6      NaN
# Name: parks_nearest, dtype: float64 count    8043.000000
# mean      491.017282
# std       342.776122
# min         1.000000
# 25%       288.000000
# 50%       455.000000
# 75%       612.000000
# max      3190.000000
# Name: parks_nearest, dtype: float64

# %% [markdown]
# Заполним пропуски по аналогии с предыдущими столбцами, привязкой к населенному пункту.

# %%
print('Медианы расстояний parks_nearest в locality_name : ')
loc_median = data.groupby('locality_name')['parks_nearest'].median().sort_values()
loc_median = loc_median.dropna()
display(loc_median.head(15))

# Функция для присваивания пропуску значения медианы
def med_insert(loc_dist):
    if loc_dist not in loc_median:
        return np.nan
    return loc_median[loc_dist]


print('Проверка работы med_insert: Зеленогорск - ', med_insert('Зеленогорск')) 
print('Проверка работы med_insert: Кронштадт - ', med_insert('Кронштадт'))
# Out:
# Медианы расстояний parks_nearest в locality_name :
# locality_name
# Зеленогорск          147.5
# Кронштадт            293.0
# Петергоф             294.0
# Павловск             312.0
# Сестрорецк           367.0
# Колпино              393.0
# Пушкин               399.5
# Ломоносов            407.0
# Красное Село         428.5
# Санкт-Петербург      460.0
# поселок Стрельна     700.0
# поселок Парголово    733.0
# Name: parks_nearest, dtype: float64
# Проверка работы med_insert: Зеленогорск -  147.5
# Проверка работы med_insert: Кронштадт -  293.0

# %%
# Выборка для проверки
print('Всего пропущенных значений в столбце =', data['parks_nearest'].isna().sum())
test_ind = data.loc[(data['locality_name']=='Санкт-Петербург') & (data['parks_nearest'].isna()==True)].index
print("Всего пропущенных значений в Санкт-Петербург =", len(test_ind))
display(data.loc[test_ind,['locality_name','parks_nearest']].head(12))
# Out:
# Всего пропущенных значений в столбце = 15576
# Всего пропущенных значений в Санкт-Петербург = 8445
#       locality_name  parks_nearest
# 7   Санкт-Петербург            NaN
# 9   Санкт-Петербург            NaN
# 17  Санкт-Петербург            NaN
# 19  Санкт-Петербург            NaN
# 25  Санкт-Петербург            NaN
# 26  Санкт-Петербург            NaN
# 31  Санкт-Петербург            NaN
# 32  Санкт-Петербург            NaN
# 34  Санкт-Петербург            NaN
# 35  Санкт-Петербург            NaN
# 39  Санкт-Петербург            NaN
# 43  Санкт-Петербург            NaN

# %%
data.loc[data['parks_nearest'].isna()==True, 'parks_nearest'] = data['locality_name'].apply(med_insert)

# %%
display(data.loc[test_ind,['locality_name','parks_nearest']].head(12))
# Out:
#       locality_name  parks_nearest
# 7   Санкт-Петербург          460.0
# 9   Санкт-Петербург          460.0
# 17  Санкт-Петербург          460.0
# 19  Санкт-Петербург          460.0
# 25  Санкт-Петербург          460.0
# 26  Санкт-Петербург          460.0
# 31  Санкт-Петербург          460.0
# 32  Санкт-Петербург          460.0
# 34  Санкт-Петербург          460.0
# 35  Санкт-Петербург          460.0
# 39  Санкт-Петербург          460.0
# 43  Санкт-Петербург          460.0

# %%
data['parks_nearest'].isna().sum()
# Out:
# 5981

# %% [markdown]
# Осталось 5996 пропусков. Оставим их по аналогии с предыдущими столбцами.

# %% [markdown]
# #### ponds_around3000

# %%
data['ponds_around3000'].value_counts(dropna=False)
# Out:
# 0.0    9058
# 1.0    5704
# NaN    5493
# 2.0    1881
# 3.0    1483
# Name: ponds_around3000, dtype: int64

# %% [markdown]
# Делаем также, как и в предыдущем столбце.

# %%
data['ponds_around3000'] = data['ponds_around3000'].fillna(0)
display(data['ponds_around3000'].value_counts(dropna=False))
data['ponds_around3000'] = data['ponds_around3000'].astype(int)
print(data['ponds_around3000'].dtype)
# Out:
# 0.0    14551
# 1.0     5704
# 2.0     1881
# 3.0     1483
# Name: ponds_around3000, dtype: int64
# int64

# %% [markdown]
# От NaN избавились, идем дальше.

# %% [markdown]
# #### ponds_nearest

# %%
describing('ponds_nearest')
# Out:
# 0    755.0
# 1      NaN
# 2    574.0
# 3    234.0
# 4     48.0
# 5      NaN
# 6      NaN
# Name: ponds_nearest, dtype: float64 count    9068.000000
# mean      518.769188
# std       277.769817
# min        13.000000
# 25%       295.000000
# 50%       503.000000
# 75%       731.000000
# max      1344.000000
# Name: ponds_nearest, dtype: float64

# %% [markdown]
# Выбросов нет. Заполняем по аналогии с предыдущими столбцами.

# %%
print('Медианы расстояний ponds_nearest в locality_name : ')
loc_median = data.groupby('locality_name')['ponds_nearest'].median().sort_values()
loc_median = loc_median.dropna()
display(loc_median.head(15))

# Функция для присваивания пропуску значения медианы
def med_insert(loc_dist):
    if loc_dist not in loc_median:
        return np.nan
    return loc_median[loc_dist]


print('Проверка работы med_insert: Сестрорецк - ', med_insert('Сестрорецк')) 
print('Проверка работы med_insert: поселок Зеленогорск - ', med_insert('Зеленогорск'))
# Out:
# Медианы расстояний ponds_nearest в locality_name :
# locality_name
# поселок Мурино        133.0
# Красное Село          225.5
# Кронштадт             312.0
# поселок Белоостров    320.0
# Сестрорецк            372.0
# поселок Саперный      419.5
# Пушкин                444.0
# Павловск              458.0
# Петергоф              474.0
# Санкт-Петербург       504.0
# Зеленогорск           507.0
# Колпино               509.0
# Ломоносов             553.0
# поселок Шушары        584.5
# поселок Парголово     593.0
# Name: ponds_nearest, dtype: float64
# Проверка работы med_insert: Сестрорецк -  372.0
# Проверка работы med_insert: поселок Зеленогорск -  507.0

# %% [markdown]
# Создадим выборку для проверки.

# %%
print('Всего пропущенных значений в столбце =', data['ponds_nearest'].isna().sum())
test_ind = data.loc[(data['locality_name']=='Санкт-Петербург') & (data['ponds_nearest'].isna()==True)].index
print("Всего пропущенных значений в Санкт-Петербург =", len(test_ind))
display(data.loc[test_ind,['locality_name','ponds_nearest']].head(5))
# Out:
# Всего пропущенных значений в столбце = 14551
# Всего пропущенных значений в Санкт-Петербург = 7742
#       locality_name  ponds_nearest
# 7   Санкт-Петербург            NaN
# 9   Санкт-Петербург            NaN
# 16  Санкт-Петербург            NaN
# 18  Санкт-Петербург            NaN
# 19  Санкт-Петербург            NaN

# %% [markdown]
# Заменим значения.

# %%
data.loc[data['ponds_nearest'].isna()==True, 'ponds_nearest'] = data['locality_name'].apply(med_insert)

# %% [markdown]
# Проверяем.

# %%
display(data.loc[test_ind,['locality_name','ponds_nearest']].head(5))
# Out:
#       locality_name  ponds_nearest
# 7   Санкт-Петербург          504.0
# 9   Санкт-Петербург          504.0
# 16  Санкт-Петербург          504.0
# 18  Санкт-Петербург          504.0
# 19  Санкт-Петербург          504.0

# %%
data['parks_nearest'].isna().sum()
# Out:
# 5981

# %% [markdown]
# Осталось 5996. Остальные оставим по аналогии с предыдущими столбцами.

# %% [markdown]
# #### days_exposition

# %%
describing('days_exposition')
# Out:
# 0      NaN
# 1     81.0
# 2    558.0
# 3    424.0
# 4    121.0
# 5     55.0
# 6    155.0
# Name: days_exposition, dtype: float64 count    20448.000000
# mean       180.745256
# std        219.681867
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        231.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %%
print('Распределение пропусков по населенным пунктам:')
loc_nan_exp = pd.DataFrame()
loc_nan_exp = data.groupby(data[data['days_exposition'].isna()==True]['locality_name'])['locality_name'].count(). \
                                                          sort_values(ascending=False)

# data.groupby(data.loc[data['days_exposition'].isna()==True,'locality_name'])['locality_name'].count(). \
#                                                                                 sort_values(ascending=False).head(20)
display(loc_nan_exp)
# Out:
# Распределение пропусков по населенным пунктам:
# locality_name
# Санкт-Петербург       2076
# Пушкин                  62
# Всеволожск              58
# Гатчина                 39
# Мурино                  34
#                       ...
# деревня Снегиревка       1
# деревня Сижно            1
# деревня Раздолье         1
# деревня Рабитицы         1
# село Старая Ладога       1
# Name: locality_name, Length: 196, dtype: int64

# %% [markdown]
# Главным фактором влиющим на скорость продажи квартиры является местоположение - locality_name
# Попробуем заполнить пропуски медианами или средними по каждому населенному пункту

# %%
print('Медианы days_exposition в locality_name : ')
loc_median = data.groupby('locality_name')['days_exposition'].median().sort_values()
loc_median = loc_median.dropna()
display(loc_median)

# Функция для присваивания пропуску значения медианы
def loc_med_insert(loc_name):
    if loc_name not in loc_median:
        return np.nan
    return loc_median[loc_name]
print('Проверка работы loc_median: поселок Любань - ', loc_med_insert('поселок Любань')) 
print('Проверка работы loc_median: Санкт-Петербург - ', loc_med_insert('Санкт-Петербург'))
# Out:
# Медианы days_exposition в locality_name :
# locality_name
# поселок Володарское              5.0
# поселок Заводской                5.0
# садовое товарищество Садко       7.0
# деревня Яльгелево                7.0
# коттеджный поселок Счастье       7.0
#                                ...
# поселок Любань                 654.0
# поселок Коробицыно             750.0
# деревня Рабитицы              1007.0
# поселок Молодежное            1043.0
# поселок Севастьяново          1069.0
# Name: days_exposition, Length: 294, dtype: float64
# Проверка работы loc_median: поселок Любань -  654.0
# Проверка работы loc_median: Санкт-Петербург -  95.0

# %%
print('Средние days_exposition в locality_name : ')
loc_mean = data.groupby('locality_name')['days_exposition'].mean().sort_values()
loc_mean = loc_mean.dropna()
display(loc_mean)

# Функция для присваивания пропуску значения медианы
def loc_mean_insert(loc_name):
    if loc_name not in loc_mean:
        return np.nan
    return loc_mean[loc_name]
print('Проверка работы loc_mean: поселок Любань - ', loc_mean_insert('поселок Любань')) 
print('Проверка работы loc_mean: Санкт-Петербург - ', loc_mean_insert('Санкт-Петербург'))
# Out:
# Средние days_exposition в locality_name :
# locality_name
# поселок Володарское              5.0
# поселок Заводской                5.0
# садовое товарищество Садко       7.0
# коттеджный поселок Счастье       7.0
# поселок Семиозерье               9.0
#                                ...
# деревня Большая Пустомержа     627.0
# поселок Коробицыно             750.0
# поселок Молодежное             786.0
# деревня Рабитицы              1007.0
# поселок Севастьяново          1069.0
# Name: days_exposition, Length: 294, dtype: float64
# Проверка работы loc_mean: поселок Любань -  531.0
# Проверка работы loc_mean: Санкт-Петербург -  182.72205105633802

# %% [markdown]
# Выберем медиану для замены пропусков (она менее чувствительна к крайним значениям)

# %%
# Контрольные значения
print(loc_med_insert('Санкт-Петербург'))
print('Санкт-Петербург', data[data['locality_name']=='Санкт-Петербург']['days_exposition'])
print()
print(loc_med_insert('деревня Заневка'))
print('деревня Заневка', data[data['locality_name']=='деревня Заневка']['days_exposition'])
print()
print(loc_med_insert('поселок Любань'))
print('поселок Любань', data[data['locality_name']=='поселок Любань']['days_exposition'])
print()
print(loc_med_insert('поселок Шугозеро'))
print('поселок Шугозеро',data[data['locality_name']=='поселок Шугозеро']['days_exposition'])
# Out:
# 95.0
# Санкт-Петербург 0          NaN
# 2        558.0
# 3        424.0
# 4        121.0
# 7          NaN
#          ...
# 23609     29.0
# 23610     15.0
# 23611    519.0
# 23614      NaN
# 23617    602.0
# Name: days_exposition, Length: 15708, dtype: float64
#
# 28.0
# деревня Заневка 1442      11.0
# 5864      28.0
# 7784     796.0
# 11371      NaN
# 13736      NaN
# 15351      NaN
# Name: days_exposition, dtype: float64
#
# 654.0
# поселок Любань 12893    788.0
# 14451    654.0
# 23312    151.0
# Name: days_exposition, dtype: float64
#
# nan
# поселок Шугозеро 18046   NaN
# Name: days_exposition, dtype: float64

# %%
# ЗАМЕНЯЕМ
data.loc[data['days_exposition'].isna()==True, 'days_exposition'] = data['locality_name'].apply(loc_med_insert)

# %%
# Проверим
print('Санкт-Петербург', data[data['locality_name']=='Санкт-Петербург']['days_exposition'])
print('деревня Заневка', data[data['locality_name']=='деревня Заневка']['days_exposition'])
print('поселок Любань', data[data['locality_name']=='поселок Любань']['days_exposition'])
print('поселок Шугозеро',data[data['locality_name']=='поселок Шугозеро']['days_exposition'])
# Out:
# Санкт-Петербург 0         95.0
# 2        558.0
# 3        424.0
# 4        121.0
# 7         95.0
#          ...
# 23609     29.0
# 23610     15.0
# 23611    519.0
# 23614     95.0
# 23617    602.0
# Name: days_exposition, Length: 15708, dtype: float64
# деревня Заневка 1442      11.0
# 5864      28.0
# 7784     796.0
# 11371     28.0
# 13736     28.0
# 15351     28.0
# Name: days_exposition, dtype: float64
# поселок Любань 12893    788.0
# 14451    654.0
# 23312    151.0
# Name: days_exposition, dtype: float64
# поселок Шугозеро 18046   NaN
# Name: days_exposition, dtype: float64

# %% [markdown]
# Проверяем количество пропусков и ищем медиану столбца.

# %%
print("Кол-во пропусков =", data['days_exposition'].isna().sum())
print()
med_day_exp = data['days_exposition'].median()
print('Медиана всего столбца =', med_day_exp)
# Out:
# Кол-во пропусков = 71
#
# Медиана всего столбца = 95.0

# %% [markdown]
# Заполним пропуска медианой столбца.

# %%
data['days_exposition'] = data['days_exposition'].fillna(med_day_exp)
print("Кол-во пропусков стало =", data['days_exposition'].isna().sum())
# Out:
# Кол-во пропусков стало = 0

# %%
data['days_exposition'].describe()
# Out:
# count    23619.000000
# mean       169.987383
# std        206.875982
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        200.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %%
data['days_exposition'] = data['days_exposition'].astype(int)
data['days_exposition'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# Столбец обработан.

# %% [markdown]
# ### Дубликаты

# %% [markdown]
# Для идентификации дубликатов возьмем совпадения по нескольким столбцам - по тем в которых были все значения изначально и в которых маловероятны совпадения:
# 1) first_day_exposition \
# 2) last_price \
# 3) total_area \
# 4) total_images

# %%
duplicated_columns = data[data[['total_images', 'last_price','first_day_exposition','total_area']].duplicated(keep=False)]
duplicated_columns.sort_values(by='total_images')
display(duplicated_columns.sort_values(by='first_day_exposition'))
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 18999             3     4370000       38.00           2016-06-23      1
# 19270             3     4370000       38.00           2016-06-23      1
# 9633              1     2533531       42.50           2016-09-08      1
# 18372             1     2533531       42.50           2016-09-08      1
# 10071            10     4400000       44.00           2017-11-22      1
# 21075            10     4400000       44.00           2017-11-22      2
# 14702            10     5142565       54.65           2018-10-01      2
# 18571            10     5142565       54.65           2018-10-01      2
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 18999             265             9         19.5      1         False  ...
# 19270             265             9         21.6      2         False  ...
# 9633              256            18         19.8      7         False  ...
# ...

# %% [markdown]
# Всего 8 значений. Думаю от них можно избавиться без явных последствий.

# %%
print("Кол-во строк до удаления",len(data))
data.drop([19013,19285,9640,18386,10078,21093,14711,18585], axis=0, inplace=True)
print("Кол-во строк после удаления",len(data))
data.reset_index(drop=True, inplace=True)
data.info()
# Out:
# Кол-во строк до удаления 23619
# Кол-во строк после удаления 23611
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23611 entries, 0 to 23610
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23611 non-null  int64
#  1   last_price            23611 non-null  int64
#  2   total_area            23611 non-null  float64
#  3   first_day_exposition  23611 non-null  datetime64[ns]
#  4   rooms                 23611 non-null  int64
#  5   ceiling_height        23611 non-null  int64
#  6   floors_total          23611 non-null  int64
#  7   living_area           23611 non-null  float64
#  8   floor                 23611 non-null  int64
#  9   is_apartment          23611 non-null  bool
#  10  studio                23611 non-null  bool
#  11  open_plan             23611 non-null  bool
#  12  kitchen_area          23462 non-null  float64
# ...

# %% [markdown]
# ### Вывод предобработки

# %% [markdown]
# Осталось 23631 строк. Изначально было 23698.
# 99% данных сохранено. Убрали выбросы по столбцам в которых это уместно и убрали дубликаты.
#
# В "matches_True" - сохранены строки в которых отсутствуют расстояния. Необходимо выяснить причину, вероятно проблема в выгрузке.
#
# + ceiling_height медианные значения, ошибочные значения были предварительно исправлены
# + first_day_exposition поменян тип данных
# + living_area и kitchen_area произвели замену используя связь между одним и другим столбцом. Учли квартиры студии, оставили в разделе kitchen NaN.
# + столбцы с площадями изменили на int в столбце с расстояниями оставили все как есть, слишком много пропусков.
# + days_exposition пропуски оформили медианами, в зависимости от населенного пункта.
# + все расстояния постарались заполнить отталкиваясь от значений в каждом населенном пункте

# %%
data['total_area'] = data['total_area'].astype('float32')
data['living_area'] = data['living_area'].astype('float32')
data['kitchen_area'] = data['kitchen_area'].astype('float32')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23611 entries, 0 to 23610
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23611 non-null  int64
#  1   last_price            23611 non-null  int64
#  2   total_area            23611 non-null  float32
#  3   first_day_exposition  23611 non-null  datetime64[ns]
#  4   rooms                 23611 non-null  int64
#  5   ceiling_height        23611 non-null  int64
#  6   floors_total          23611 non-null  int64
#  7   living_area           23611 non-null  float32
#  8   floor                 23611 non-null  int64
#  9   is_apartment          23611 non-null  bool
#  10  studio                23611 non-null  bool
#  11  open_plan             23611 non-null  bool
#  12  kitchen_area          23462 non-null  float32
#  13  balcony               23611 non-null  float64
#  14  locality_name         23611 non-null  object
# ...

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %% [markdown]
# ### Цена квадратного метра

# %%
data['square_metr_price'] = data['last_price'] / data['total_area']
data['square_metr_price'] = data['square_metr_price'].astype(int)
display(data['square_metr_price'].sample(3))
display(data.sample(3))
data['square_metr_price'].dtype
# Out:
# 4230      36697
# 23028    101391
# 19830     33653
# Name: square_metr_price, dtype: int64
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 19435            10     8000000       118.0           2017-08-31      3
# 12982            10     5900000        53.0           2017-12-17      2
# 18953             5     3100000        31.0           2018-11-03      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 19435             300             5         36.0      4         False  ...
# 12982             300             5         33.0      4         False  ...
# 18953             265             5         18.0      2         False  ...
#
#        balcony    locality_name  airports_nearest  cityCenters_nearest  \
# 19435      4.0           Пушкин           18616.0              30770.0
# 12982      0.0  Санкт-Петербург           14163.0               8304.0
# ...

# %% [markdown]
# ### День недели, месяц и год публикации объявления

# %%
data['day_exp'] = data['first_day_exposition'].dt.weekday
data['month_exp'] = data['first_day_exposition'].dt.month
data['year_exp'] = data['first_day_exposition'].dt.year
display(data[['day_exp', 'month_exp', 'year_exp']].sample(5))
display(data.sample(5))
# Out:
#        day_exp  month_exp  year_exp
# 22552        4          1      2018
# 23480        1          4      2019
# 5364         0          7      2017
# 12579        4          8      2018
# 7872         4          3      2017
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 20222            21     6750000   71.800003           2017-10-07      3
# 21343             4     1870000   20.000000           2018-03-06      1
# 15427            15     3050000   36.000000           2017-09-21      1
# 11776             8     5500000   79.099998           2015-07-08      2
# 4435              2     4435000   40.110001           2017-04-26      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 20222             300             8    36.900002      4         False  ...
# 21343             250             5    14.000000      1         False  ...
# 15427             252             5    18.000000      4         False  ...
# ...

# %% [markdown]
# ### Этаж квартиры; варианты — первый, последний, другой (firtst, last, other)

# %%
data['cat_floor'] = np.nan # Новый столбец - категории этажа: первый, последний, другой 

def floor_insert(row):
    if row['floor']==1:
        return 'первый'
    elif row['floor']==row['floors_total']:
        return 'последний'
    else:
        return 'другой'

data['cat_floor'] = data.apply(floor_insert, axis=1)

print(data['cat_floor'].value_counts(dropna=False))
# Out:
# другой       17378
# последний     3326
# первый        2907
# Name: cat_floor, dtype: int64

# %% [markdown]
# ### Cоотношение жилой и общей площади, а также отношение площади кухни к общей.

# %%
data['liv_tot'] = round(data['kitchen_area'] / data['total_area'],2)
data['kit_tot'] = round(data['kitchen_area'] / data['total_area'],2)
display(data[['liv_tot', 'kit_tot']])
# Out:
#        liv_tot  kit_tot
# 0         0.23     0.23
# 1         0.27     0.27
# 2         0.15     0.15
# 3         0.17     0.17
# 4         0.40     0.40
# ...        ...      ...
# 23606     0.10     0.10
# 23607     0.14     0.14
# 23608     0.17     0.17
# 23609     0.30     0.30
# 23610     0.28     0.28
#
# [23611 rows x 2 columns]

# %% [markdown]
# Все готово. Необходимые столбцы добавлены.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Изучение параметров - площадь, цена, число комнат, высота потолков. Построение гистограммы для каждого параметра.

# %%
describing('total_area')
# Out:
# 0    108.000000
# 1     40.400002
# 2     56.000000
# 3    159.000000
# 4    100.000000
# 5     30.400000
# 6     37.299999
# Name: total_area, dtype: float32 count    23611.000000
# mean        59.918079
# std         33.423180
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.599998
# max        590.000000
# Name: total_area, dtype: float64

# %%
data['total_area'].hist(range=(20,100),figsize=(14,3), bins=100)
# Out:
# <AxesSubplot:>

# %% [markdown]
# По данным видно что самые популярные по площади это квартиры в районе 30-45 кв метров. Это 1-2 комнатные квартиры. Потом идёт всплеск популярности в районе 60. И все что больше уже идёт на угасание.

# %%
describing('last_price')
# Out:
# 0    13000000
# 1     3350000
# 2     5196000
# 3    64900000
# 4    10000000
# 5     2890000
# 6     3700000
# Name: last_price, dtype: int64 count    2.361100e+04
# mean     6.252588e+06
# std      6.415021e+06
# min      4.300000e+05
# 25%      3.402500e+06
# 50%      4.646000e+06
# 75%      6.760000e+06
# max      9.900000e+07
# Name: last_price, dtype: float64

# %%
data['last_price'].hist(range=(0,10000000),figsize=(10,3), bins=150)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Пик продаж идёт в районе 4 млн. рублей. Потом идёт равномерное падание спроса на более дорогие квартиры. Диапазон от 600 до 800 примерно равномерный. Ну и далее идут более дорогие варианты.

# %%
describing('rooms')
# Out:
# 0    3
# 1    1
# 2    2
# 3    3
# 4    2
# 5    1
# 6    1
# Name: rooms, dtype: int64 count    23611.000000
# mean         2.074796
# std          1.057634
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         19.000000
# Name: rooms, dtype: float64

# %% [markdown]
# Весьма очевидно, что популярнее всего однокомнатные квартиры. Далее идут двухкомнатные и на убывание. 4 и 5 комнатные пользуются наименьшим спросом. Все что выше имеет единичные случаи.

# %%
describing('ceiling_height')
# Out:
# 0    270
# 1    265
# 2    265
# 3    265
# 4    303
# 5    265
# 6    265
# Name: ceiling_height, dtype: int64 count    23611.000000
# mean       269.584727
# std         21.715093
# min        240.000000
# 25%        260.000000
# 50%        265.000000
# 75%        270.000000
# max        580.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Самые популярные потолки находятся в районе 250-270 см.

# %% [markdown]
# ### Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?

# %%
describing('days_exposition')
# Out:
# 0     95
# 1     81
# 2    558
# 3    424
# 4    121
# 5     55
# 6    155
# Name: days_exposition, dtype: int64 count    23611.000000
# mean       170.009064
# std        206.901185
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        200.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %%
data['days_exposition'].hist(range=(10,365),figsize=(16,5), bins=100)
# Out:
# <AxesSubplot:>

# %%
data['days_exposition'].mean()
# Out:
# 170.00906357206387

# %%
data['days_exposition'].median()
# Out:
# 95.0

# %% [markdown]
# В среднем продажи занимают от 3 до 6 месяцев. Пик продаж приходится примерно на 95 день. Соответственно все что менее я бы назвал быстрой продажей.

# %% [markdown]
# ### Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили.

# %% [markdown]
# * Все уже было убрано на этапе предобработки.
# * Были сильно большие значения стоимости, так и слишком маленькие, нереалистичные (Суммы были похожи на сдачу в аренду, но мы этот вариант не рассматривали и просто их убрали).
# * Убрали нулевые значения комнат.
# * Убрали слишком низкие и слишком высокие значения потолка, заменили вероятные опечатки на правильные значения.
# * В площадях убрали слишком маленькие и слишком большие значения. Вероятнее всего это были опечатки в нулях. Исправили.
# * Убрали в местоположениях дубликаты, привели к общему виду там где это было возможно.
# * В столбцах с расстояниями все было похуже, очень много незаполненых столбцов. Где было возможно - там заполнили. В остальных столбцах пропуски не трогали, т.к. они ни на что не повлияют.

# %% [markdown]
# ### Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от площади, числа комнат, удалённости от центра. Изучите зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом. Также изучите зависимость от даты размещения: дня недели, месяца и года.

# %% [markdown]
# #### Зависимость цены от площади

# %%
def correlation(column):
    print('Зависимость от',column , data['last_price'].corr(data[column]))
    data.plot(x=column, y='last_price', kind='scatter', grid=True, figsize=(16,5), alpha=0.5);

correlation('total_area')
# Out:
# Зависимость от total_area 0.7684997723430442

# %% [markdown]
# **Все логично, чем больше площадь, тем больше цена.**

# %% [markdown]
# #### Зависимость от количества комнат

# %%
correlation('rooms')
# Out:
# Зависимость от rooms 0.47646481518666745

# %% [markdown]
# **Сильная зависимость просслеживается от 1 до 3 комнат. Все что более, меньше зависит от этого фактора.**

# %% [markdown]
# #### Зависимость от удаленности от центра

# %%
correlation('cityCenters_nearest')
# Out:
# Зависимость от cityCenters_nearest -0.3085334805366334

# %% [markdown]
# **Квартиры в центре безусловно дороже. Но также имеется всплеск цен на удалении от центра порядка 50 км. Вероятнее всего там просто населенный пункт (Сертолово например).**

# %% [markdown]
# #### Зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом

# %%
floor_price = data.groupby('cat_floor')['last_price'].mean();
floor_price.plot(x=floor_price.index, y=floor_price.values, kind='bar', grid=True, figsize=(3,4));

# %% [markdown]
# **По гистограмме четко видно, что первый этаж люди любят меньше всего.**

# %% [markdown]
# ### Изучите зависимость от даты размещения: дня недели, месяца и года.

# %%
correlation('day_exp')
# Out:
# Зависимость от day_exp -0.0031845289556767073

# %%
correlation('month_exp')
# Out:
# Зависимость от month_exp 0.007528893299444069

# %%
correlation('year_exp')
# Out:
# Зависимость от year_exp -0.05422530924061831

# %%
data.plot.hexbin(x='day_exp', y='last_price', gridsize = 25, sharex=False,grid=True, ylim=(0,15000000));

# %%
data.plot.hexbin(x='month_exp', y='last_price', gridsize = 25, sharex=False,grid=True, ylim=(0,15000000));

# %%
data.plot.hexbin(x='year_exp', y='last_price', gridsize = 25, sharex=False,grid=True, ylim=(0,15000000));

# %% [markdown]
# Цена не зависит от дня размещения, месяца или года. Единственное что зависит - количество размещений.

# %% [markdown]
# *Больше всего зависит цена от площади квартиры, а также от расстояния к центру города, количества комнат и этажа. В то же время дата размещения не влияет на цену.*

# %%
new_correlation = data[['last_price', 'total_area', 'rooms', 'cityCenters_nearest']].corr()

# %%
new_correlation.plot.line('last_price')
# Out:
# <AxesSubplot:xlabel='last_price'>

# %% [markdown]
# По данной корреляции видно зависимость на расстояние от центра, чем дальше тем дешевле. Чем больше площадь, тем дороже. И дороже всего среднее количество комнат (Вероятнее всего 2).

# %%
import seaborn as sns

# %%
sns.pairplot(new_correlation)

# %% [markdown]
# ### Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите среди них населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце 'locality_name'.

# %%
loc10 = data.groupby('locality_name')['square_metr_price'].agg(['count', 'mean']).sort_values(by='count', ascending=False).head(10)
loc10.columns = ['flats', 'square_metr_price']
loc10.reset_index(inplace=True)

print(loc10)
print()

print('Самая низкая стоимость за квадратный метр:')
print()
print(loc10.loc[loc10['square_metr_price']==loc10['square_metr_price'].min()])
print()
print('Самая высокая стоимость за квадратный метр:')
print()
print(loc10.loc[loc10['square_metr_price']==loc10['square_metr_price'].max()])
# Out:
#        locality_name  flats  square_metr_price
# 0    Санкт-Петербург  15703      113553.533847
# 1     поселок Мурино    556       85681.298561
# 2     поселок Шушары    440       78676.900000
# 3         Всеволожск    397       68718.853904
# 4             Пушкин    369      103125.373984
# 5            Колпино    337       75414.816024
# 6  поселок Парголово    327       90175.486239
# 7            Гатчина    307       68745.693811
# 8    деревня Кудрово    299       92473.073579
# 9             Выборг    235       58237.723404
#
# Самая низкая стоимость за квадратный метр:
#
#   locality_name  flats  square_metr_price
# 9        Выборг    235       58237.723404
#
# Самая высокая стоимость за квадратный метр:
#
#      locality_name  flats  square_metr_price
# 0  Санкт-Петербург  15703      113553.533847

# %% [markdown]
# ### Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге ('locality_name'). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона.

# %%
spb_distance = data.loc[data['locality_name']=='Санкт-Петербург',['square_metr_price', 'cityCenters_nearest']].reset_index(drop=True)
spb_distance['dist_center'] = round(spb_distance['cityCenters_nearest']/1000).astype(int)
print(spb_distance.sample(10))
# Out:
#        square_metr_price  cityCenters_nearest  dist_center
# 8832               88181              21401.0           21
# 5928               76923               5886.0            6
# 9455               80434              15676.0           16
# 14144             116250              14612.0           15
# 6778              118055              10337.0           10
# 4945               77368              19014.0           19
# 4438              100952               4532.0            5
# 2465               91398               3671.0            4
# 7579              129679              12218.0           12
# 8190               98000              15837.0           16

# %%
price_km_spb = spb_distance.pivot_table(index='dist_center', values='square_metr_price', aggfunc='mean')
price_km_spb.head(8)
# Out:
#              square_metr_price
# dist_center
# 0                231767.538462
# 1                154784.367021
# 2                148411.065574
# 3                121299.210227
# 4                128244.621739
# 5                137383.194536
# 6                145970.459016
# 7                153122.882494

# %%
price_km_spb.plot(kind='bar', grid=True, figsize=(20,5))
# Out:
# <AxesSubplot:xlabel='dist_center'>

# %% [markdown]
# По гистограмме отчетливо видно, что на расстоянии до 1 км, цены за квадратный метр очень высока. И падает по мере удаления от центра. Всплеск идет на 27 км. Вероятнее всего пригородные города напр. Сертолово.

# %% [markdown]
# ### Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всему городу?

# %%
spb_center_seq = data.query('cityCenters_nearest < 8000 ') #Квартиры в центре
display(spb_center_seq.sample(3))
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 1868            12    11490000        74.0           2016-08-31      3
# 1085            10     4950000        36.0           2017-11-29      1
# 9805             5     5950000        59.0           2018-03-17      2
#
#       ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 1868             270             5    45.400002      5         False  ...
# 1085             250            14    17.700001      2         False  ...
# 9805             250            18    53.000000      9         False  ...
#
#       ponds_around3000  ponds_nearest  days_exposition  square_metr_price  \
# 1868                 2           29.0              469             155270
# 1085                 3          341.0               66             137500
# 9805                 2          938.0              150             100847
#
#      day_exp  month_exp  year_exp  cat_floor  liv_tot  kit_tot
# ...

# %%
spb_all_seq = data.query(' locality_name == "Санкт-Петербург" ') #Квартиры во всем городе
display(spb_all_seq.sample(3))
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 4349             6     3800000   33.000000           2016-09-15      1
# 2174             9     5990000   73.000000           2018-08-11      3
# 8331            13     8200000   81.099998           2019-04-26      4
#
#       ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 4349             270            16    15.500000     13         False  ...
# 2174             300             5    49.000000      3         False  ...
# 8331             340             6    59.599998      2         False  ...
#
#       ponds_around3000  ponds_nearest  days_exposition  square_metr_price  \
# 4349                 0          504.0              385             115151
# 2174                 1          186.0              111              82054
# 8331                 0          504.0               95             101109
#
#      day_exp  month_exp  year_exp  cat_floor  liv_tot  kit_tot
# ...

# %%
for col in ['total_area', 'last_price', 'rooms', 'ceiling_height']:
    spb_center_seq.plot(y=col, kind='hist', grid=True, figsize=(14,3), bins=75, alpha=0.8, legend=True, label='Центр '+col);
    spb_all_seq.plot(y=col, kind='hist', grid=True, figsize=(14,3), bins=75, alpha=0.5, legend=True, label='Остальной Питер - '+col);
    plt.show()

# %% [markdown]
# + В центре продаются квартиры с большей площадью
# + Цена квартир в центре выше
# + В цетре в основном продаются квартиры многокомнатные, в отдалении от центра в основном однушки.
# + В центре много квартир с высокими потолками (старый фонд)

# %% [markdown]
# ### Сравнение центра и остального Петербурга

# %% [markdown]
# Необходимо для начала выделить факторы, которые влияют на цену в обоих регионах. После этого уже сравнить.

# %%
def corr_spb(column):   
    plt.show()
    print('Корелляция цены в ЦЕНТР от',column , spb_center_seq['last_price'].corr(spb_center_seq[column]))
    spb_center_seq.plot(x=column, y='last_price', kind='scatter', grid=True, figsize=(14,4));
    plt.show()
    print('Корелляция цены в ПИТЕР от',column , spb_all_seq['last_price'].corr(spb_all_seq[column]))
    spb_all_seq.plot(x=column, y='last_price', kind='scatter', grid=True, figsize=(14,4));

for сol in ['rooms', 'floor', 'cityCenters_nearest', 'day_exp', 'month_exp', 'year_exp']:
    corr_spb(сol)



# Зависимости от Категории этажа (первый, последний другой)
# Вычислим среднюю цену в каждой категории
plt.show()
cat_fl_mean_spb_center = spb_center_seq.groupby('cat_floor')['last_price'].mean();
cat_fl_mean_spb_all = spb_all_seq.groupby('cat_floor')['last_price'].mean();
print('ЦЕНТР')
plt.show()
cat_fl_mean_spb_center.plot(x=cat_fl_mean_spb_center.index, y=cat_fl_mean_spb_center.values, kind='bar', grid=True, figsize=(5,4), alpha=0.5);
plt.show()
print('ПИТЕР')
cat_fl_mean_spb_all.plot(x=cat_fl_mean_spb_all.index, y=cat_fl_mean_spb_all.values, kind='bar', grid=True, figsize=(5,4), alpha=0.5);
# Out:
# Корелляция цены в ЦЕНТР от rooms 0.4147587604104588
# Корелляция цены в ПИТЕР от rooms 0.4916810261916586
# Корелляция цены в ЦЕНТР от floor 0.13197561435282504
# Корелляция цены в ПИТЕР от floor -0.008868148279624418
# Корелляция цены в ЦЕНТР от cityCenters_nearest -0.060101888098616364
# Корелляция цены в ПИТЕР от cityCenters_nearest -0.36905305745123174
# Корелляция цены в ЦЕНТР от day_exp 0.01999945336132733
# Корелляция цены в ПИТЕР от day_exp 0.0025612692514789138
# Корелляция цены в ЦЕНТР от month_exp 0.000677302354806918
# Корелляция цены в ПИТЕР от month_exp 0.00409223839233794
# Корелляция цены в ЦЕНТР от year_exp -0.054548608504380744
# Корелляция цены в ПИТЕР от year_exp -0.055388866642280335
# ЦЕНТР
# ПИТЕР

# %%
sns.pairplot(new_correlation)

# %% [markdown]
# ***Вывод:
# В центре города, количество комнат практически не влияет на цену
# В городе расстояние от центра имеет прямое влияние на цену, при этом в пригороде сильного влияния не прослеживается
# По остальным параметрам зависимости не прослеживаются.***

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# В процессе предобработки были заполнены пропуски по ситуации.
# Были столбцы, которые заполнить не удалось. На результат они не повлияли.
# Поскольку при заполнении средним значением или медианой, результат мог повлиять на исследования.
#
# В "matches_True" вскрылась ошибка, вероятно при записи. Необходимо отправить багрепорт разработчикам.
# Все столбцы с расстоянием заполнялись с зависимость расстояние - населенный пункт.
# Добавили необходимые расчеты/столбцы для ответа на поставленные вопросы.
#
# Самое большое количество продаваемых квартир - однокомнатные, потом идут двухкомнатные и т.д. по возрастанию.
# Наиболее популярная цена на квартиры в районе от 3 до 8 млн.
# Практически везде стандарт потолков 265 см.
#
# Самое большое влияние на стоимость имеет площадь. Потом идет удаление от центра и кол-во комнат.
# На расстоянии до 1 км от центра цена очень высока и довольно резко меняется на расстоянии после.
# В центре также квартиры с самыми большимы площадями и потолками. Здесь наверное подразумевается большое количество домов "старого фонда.
